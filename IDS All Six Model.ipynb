# %%
# !pip install pandas
# Out:
# Requirement already satisfied: pandas in /opt/conda/lib/python3.10/site-packages (2.1.4)
# Requirement already satisfied: numpy<2,>=1.22.4 in /opt/conda/lib/python3.10/site-packages (from pandas) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/conda/lib/python3.10/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/lib/python3.10/site-packages (from pandas) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in /opt/conda/lib/python3.10/site-packages (from pandas) (2023.4)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.10/site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)

# %%
# !pip install keras-metrics
# Out:
# Collecting keras-metrics
#   Downloading keras_metrics-1.1.0-py2.py3-none-any.whl.metadata (3.2 kB)
# Requirement already satisfied: Keras>=2.1.5 in /opt/conda/lib/python3.10/site-packages (from keras-metrics) (3.0.5)
# Requirement already satisfied: absl-py in /opt/conda/lib/python3.10/site-packages (from Keras>=2.1.5->keras-metrics) (1.4.0)
# Requirement already satisfied: numpy in /opt/conda/lib/python3.10/site-packages (from Keras>=2.1.5->keras-metrics) (1.26.4)
# Requirement already satisfied: rich in /opt/conda/lib/python3.10/site-packages (from Keras>=2.1.5->keras-metrics) (13.7.0)
# Requirement already satisfied: namex in /opt/conda/lib/python3.10/site-packages (from Keras>=2.1.5->keras-metrics) (0.0.7)
# Requirement already satisfied: h5py in /opt/conda/lib/python3.10/site-packages (from Keras>=2.1.5->keras-metrics) (3.10.0)
# Requirement already satisfied: dm-tree in /opt/conda/lib/python3.10/site-packages (from Keras>=2.1.5->keras-metrics) (0.1.8)
# Requirement already satisfied: ml-dtypes in /opt/conda/lib/python3.10/site-packages (from Keras>=2.1.5->keras-metrics) (0.2.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /opt/conda/lib/python3.10/site-packages (from rich->Keras>=2.1.5->keras-metrics) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /opt/conda/lib/python3.10/site-packages (from rich->Keras>=2.1.5->keras-metrics) (2.17.2)
# Requirement already satisfied: mdurl~=0.1 in /opt/conda/lib/python3.10/site-packages (from markdown-it-py>=2.2.0->rich->Keras>=2.1.5->keras-metrics) (0.1.2)
# Downloading keras_metrics-1.1.0-py2.py3-none-any.whl (5.6 kB)
# Installing collected packages: keras-metrics
# Successfully installed keras-metrics-1.1.0

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split, StratifiedKFold
from sklearn.preprocessing import StandardScaler, LabelEncoder, MinMaxScaler, RobustScaler, Normalizer
from sklearn.impute import SimpleImputer
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier, AdaBoostClassifier
from sklearn.neural_network import MLPClassifier
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score, f1_score, precision_score, recall_score, roc_auc_score
from sklearn.feature_selection import mutual_info_classif
from sklearn.mixture import BayesianGaussianMixture
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from tqdm import tqdm

# %%
def load_data(train_path, test_path):
    # Load data from CSV files
    train_data = pd.read_csv(train_path)
    test_data = pd.read_csv(test_path)
    return train_data, test_data

# %%
def preprocess_data(data):
    # Handle missing values (e.g., using SimpleImputer)
    imputer = SimpleImputer(strategy='mean')
    data = pd.DataFrame(imputer.fit_transform(data))

    # Feature engineering (placeholder for domain knowledge-based features)
    # ... (implement domain knowledge-based feature creation here)

    # Scaling/normalization (using StandardScaler for now)
    scaler = StandardScaler()
    data = pd.DataFrame(scaler.fit_transform(data))

    # Encode categorical features (using LabelEncoder)
    label_encoder = LabelEncoder()
    for col in data.select_dtypes(include=['object']):
        data.loc[:, col] = label_encoder.fit_transform(data[col])

    return data

# %%
def create_features(data):
    # Implement domain knowledge-based feature creation here
    # ... (e.g., calculate ratios, time-based statistics)
    return data

# %%
def select_features(X, y):
    # Feature selection using mutual information or other techniques
    mutual_info = mutual_info_classif(X, y, random_state=42)
    mi_scores = pd.Series(mutual_info, index=X.columns, name='Mutual Information Score')
    mi_scores = mi_scores.sort_values(ascending=False)
    selected_features = mi_scores.head(n_features).index  # Select top n features
    return X[selected_features]

# %% [markdown]
# # Load Dataset

# %%
train = pd.read_csv("/kaggle/input/unsw-nb15/UNSW_NB15_training-set.csv")
test = pd.read_csv("/kaggle/input/unsw-nb15/UNSW_NB15_testing-set.csv")

# %%
df = pd.concat([train,test]).reset_index(drop=True)

# %%
df
# Out:
#             id       dur proto service state  spkts  dpkts  sbytes  dbytes  \
# 0            1  0.000011   udp       -   INT      2      0     496       0
# 1            2  0.000008   udp       -   INT      2      0    1762       0
# 2            3  0.000005   udp       -   INT      2      0    1068       0
# 3            4  0.000006   udp       -   INT      2      0     900       0
# 4            5  0.000010   udp       -   INT      2      0    2126       0
# ...        ...       ...   ...     ...   ...    ...    ...     ...     ...
# 257668  175337  0.000009   udp     dns   INT      2      0     114       0
# 257669  175338  0.505762   tcp       -   FIN     10      8     620     354
# 257670  175339  0.000009   udp     dns   INT      2      0     114       0
# 257671  175340  0.000009   udp     dns   INT      2      0     114       0
# 257672  175341  0.000009   udp     dns   INT      2      0     114       0
#
#                  rate  ...  ct_dst_sport_ltm  ct_dst_src_ltm  is_ftp_login  \
# 0        90909.090200  ...                 1               2             0
# 1       125000.000300  ...                 1               2             0
# 2       200000.005100  ...                 1               3             0
# 3       166666.660800  ...                 1               3             0
# 4       100000.002500  ...                 1               3             0
# ...               ...  ...               ...             ...           ...
# 257668  111111.107200  ...                13              24             0
# 257669      33.612649  ...                 1               2             0
# 257670  111111.107200  ...                 3              13             0
# 257671  111111.107200  ...                14              30             0
# 257672  111111.107200  ...                16              30             0
#
#         ct_ftp_cmd  ct_flw_http_mthd  ct_src_ltm  ct_srv_dst  is_sm_ips_ports  \
# 0                0                 0           1           2                0
# 1                0                 0           1           2                0
# 2                0                 0           1           3                0
# 3                0                 0           2           3                0
# 4                0                 0           2           3                0
# ...            ...               ...         ...         ...              ...
# 257668           0                 0          24          24                0
# 257669           0                 0           1           1                0
# 257670           0                 0           3          12                0
# 257671           0                 0          30          30                0
# 257672           0                 0          30          30                0
#
#         attack_cat  label
# 0           Normal      0
# 1           Normal      0
# 2           Normal      0
# 3           Normal      0
# 4           Normal      0
# ...            ...    ...
# 257668     Generic      1
# 257669   Shellcode      1
# 257670     Generic      1
# 257671     Generic      1
# 257672     Generic      1
#
# [257673 rows x 45 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 257673 entries, 0 to 257672
# Data columns (total 45 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   id                 257673 non-null  int64
#  1   dur                257673 non-null  float64
#  2   proto              257673 non-null  object
#  3   service            257673 non-null  object
#  4   state              257673 non-null  object
#  5   spkts              257673 non-null  int64
#  6   dpkts              257673 non-null  int64
#  7   sbytes             257673 non-null  int64
#  8   dbytes             257673 non-null  int64
#  9   rate               257673 non-null  float64
#  10  sttl               257673 non-null  int64
#  11  dttl               257673 non-null  int64
#  12  sload              257673 non-null  float64
#  13  dload              257673 non-null  float64
#  14  sloss              257673 non-null  int64
#  15  dloss              257673 non-null  int64
#  16  sinpkt             257673 non-null  float64
#  17  dinpkt             257673 non-null  float64
#  18  sjit               257673 non-null  float64
#  19  djit               257673 non-null  float64
#  20  swin               257673 non-null  int64
#  21  stcpb              257673 non-null  int64
#  22  dtcpb              257673 non-null  int64
#  23  dwin               257673 non-null  int64
#  24  tcprtt             257673 non-null  float64
#  25  synack             257673 non-null  float64
#  26  ackdat             257673 non-null  float64
#  27  smean              257673 non-null  int64
#  28  dmean              257673 non-null  int64
#  29  trans_depth        257673 non-null  int64
#  30  response_body_len  257673 non-null  int64
#  31  ct_srv_src         257673 non-null  int64
#  32  ct_state_ttl       257673 non-null  int64
#  33  ct_dst_ltm         257673 non-null  int64
#  34  ct_src_dport_ltm   257673 non-null  int64
#  35  ct_dst_sport_ltm   257673 non-null  int64
#  36  ct_dst_src_ltm     257673 non-null  int64
#  37  is_ftp_login       257673 non-null  int64
#  38  ct_ftp_cmd         257673 non-null  int64
#  39  ct_flw_http_mthd   257673 non-null  int64
#  40  ct_src_ltm         257673 non-null  int64
#  41  ct_srv_dst         257673 non-null  int64
#  42  is_sm_ips_ports    257673 non-null  int64
#  43  attack_cat         257673 non-null  object
#  44  label              257673 non-null  int64
# dtypes: float64(11), int64(30), object(4)
# memory usage: 88.5+ MB

# %% [markdown]
# # About Dataset

# %% [markdown]
# | No. | Name                | Type     | Description                                                                               |
# |-----|---------------------|----------|-------------------------------------------------------------------------------------------|
# | 1   | srcip               | nominal  | Source IP address                                                                         |
# | 2   | sport               | integer  | Source port number                                                                        |
# | 3   | dstip               | nominal  | Destination IP address                                                                    |
# | 4   | dsport              | integer  | Destination port number                                                                   |
# | 5   | proto               | nominal  | Transaction protocol                                                                     |
# | 6   | state               | nominal  | Indicates the state and its dependent protocol, e.g., ACC, CLO, CON, ECO, ECR, FIN, INT, MAS, PAR,...|
# | 7   | dur                 | Float    | Record total duration                                                                    |
# | 8   | sbytes              | integer  | Source to destination transaction bytes                                                   |
# | 9   | dbytes              | integer  | Destination to source transaction bytes                                                   |
# | 10  | sttl                | integer  | Source to destination time to live value                                                  |
# | 11  | dttl                | integer  | Destination to source time to live value                                                  |
# | 12  | sloss               | integer  | Source packets retransmitted or dropped                                                  |
# | 13  | dloss               | integer  | Destination packets retransmitted or dropped                                             |
# | 14  | service             | nominal  | http, ftp, smtp, ssh, dns, ftp-data, irc and (-) if not much used service                 |
# | 15  | Sload               | Float    | Source bits per second                                                                   |
# | 16  | Dload               | Float    | Destination bits per second                                                              |
# | 17  | Spkts               | integer  | Source to destination packet count                                                       |
# | 18  | Dpkts               | integer  | Destination to source packet count                                                       |
# | 19  | swin                | integer  | Source TCP window advertisement value                                                    |
# | 20  | dwin                | integer  | Destination TCP window advertisement value                                               |
# | 21  | stcpb               | integer  | Source TCP base sequence number                                                           |
# | 22  | dtcpb               | integer  | Destination TCP base sequence number                                                      |
# | 23  | smeansz             | integer  | Mean of the flow packet size transmitted by the source                                    |
# | 24  | dmeansz             | integer  | Mean of the flow packet size transmitted by the destination                               |
# | 25  | trans_depth         | integer  | Represents the pipelined depth into the connection of http request/response transaction   |
# | 26  | res_bdy_len         | integer  | Actual uncompressed content size of the data transferred from the server’s http service   |
# | 27  | Sjit                | Float    | Source jitter (mSec)                                                                     |
# | 28  | Djit                | Float    | Destination jitter (mSec)                                                                |
# | 29  | Stime               | Timestamp| Record start time                                                                        |
# | 30  | Ltime               | Timestamp| Record last time                                                                         |
# | 31  | Sintpkt             | Float    | Source interpacket arrival time (mSec)                                                   |
# | 32  | Dintpkt             | Float    | Destination interpacket arrival time (mSec)                                              |
# | 33  | tcprtt              | Float    | TCP connection setup round-trip time, the sum of ‘synack’ and ‘ackdat’                    |
# | 34  | synack              | Float    | TCP connection setup time, the time between the SYN and the SYN_ACK packets                |
# | 35  | ackdat              | Float    | TCP connection setup time, the time between the SYN_ACK and the ACK packets                |
# | 36  | is_sm_ips_ports     | Binary   | If source (1) and destination (3) IP addresses equal and port numbers (2)(4) equal then, this variable...|
# | 37  | ct_state_ttl        | Integer  | No. for each state (6) according to specific range of values for source/destination time to live (10...|
# | 38  | ct_flw_http_mthd    | Integer  | No. of flows that has methods such as Get and Post in http service                         |
# | 39  | is_ftp_login        | Binary   | If the FTP session is accessed by user and password then 1 else 0                            |
# | 40  | ct_ftp_cmd          | integer  | No of flows that has a command in FTP session                                             |
# | 41  | ct_srv_src          | integer  | No. of connections that contain the same service (14) and source address (1) in 100 connections...|
# | 42  | ct_srv_dst          | integer  | No. of connections that contain the same service (14) and destination address (3) in 100 connections...|
# | 43  | ct_dst_ltm          | integer  | No. of connections of the same destination address (3) in 100 connections according to the last time...|
# | 44  | ct_src_ltm          | integer  | No. of connections of the same source address (1) in 100 connections according to the last time (26)...
# | 45  | ct_src_dport_ltm    | integer  | No of connections of the same source address (1) and the destination port (4) in 100 connections acc...|
# | 46  | ct_dst_sport_ltm   | integer  | No of connections of the same destination address (3) and the source port (2) in 100 connections acc...|
# | 47  | ct_dst_src_ltm     | integer  | No of connections of the same source (1) and the destination (3) address in 100 connections according...|
# | 48  | attack_cat          | nominal  | The name of each attack category. In this data set, nine categories e.g. Fuzzers, Analysis, Backdoo...|
# | 49  | Label               | binary   | 0 for normal and 1 for attack records                                                    |

# %% [markdown]
# # EDA

# %%
import matplotlib.pyplot as plt

# Now you can use plt.style.use('fivethirtyeight')
plt.style.use('fivethirtyeight')

# %% [markdown]
# ## Check Data Balance

# %%
label_distribution = df['label'].value_counts()
plt.figure(figsize=(6, 6))
label_distribution.plot(kind='pie', autopct='%1.1f%%', colors=['skyblue', 'lightcoral'])
plt.title('Distribution of the target variable (Label)')
plt.show()

# %% [markdown]
# # Drop label to EDA

# %%
dfEDA = df.drop(['label'],axis=1)

# %%
dfEDA
# Out:
#             id       dur proto service state  spkts  dpkts  sbytes  dbytes  \
# 0            1  0.000011   udp       -   INT      2      0     496       0
# 1            2  0.000008   udp       -   INT      2      0    1762       0
# 2            3  0.000005   udp       -   INT      2      0    1068       0
# 3            4  0.000006   udp       -   INT      2      0     900       0
# 4            5  0.000010   udp       -   INT      2      0    2126       0
# ...        ...       ...   ...     ...   ...    ...    ...     ...     ...
# 257668  175337  0.000009   udp     dns   INT      2      0     114       0
# 257669  175338  0.505762   tcp       -   FIN     10      8     620     354
# 257670  175339  0.000009   udp     dns   INT      2      0     114       0
# 257671  175340  0.000009   udp     dns   INT      2      0     114       0
# 257672  175341  0.000009   udp     dns   INT      2      0     114       0
#
#                  rate  ...  ct_src_dport_ltm  ct_dst_sport_ltm  \
# 0        90909.090200  ...                 1                 1
# 1       125000.000300  ...                 1                 1
# 2       200000.005100  ...                 1                 1
# 3       166666.660800  ...                 2                 1
# 4       100000.002500  ...                 2                 1
# ...               ...  ...               ...               ...
# 257668  111111.107200  ...                24                13
# 257669      33.612649  ...                 1                 1
# 257670  111111.107200  ...                 3                 3
# 257671  111111.107200  ...                30                14
# 257672  111111.107200  ...                30                16
#
#         ct_dst_src_ltm  is_ftp_login  ct_ftp_cmd  ct_flw_http_mthd  \
# 0                    2             0           0                 0
# 1                    2             0           0                 0
# 2                    3             0           0                 0
# 3                    3             0           0                 0
# 4                    3             0           0                 0
# ...                ...           ...         ...               ...
# 257668              24             0           0                 0
# 257669               2             0           0                 0
# 257670              13             0           0                 0
# 257671              30             0           0                 0
# 257672              30             0           0                 0
#
#         ct_src_ltm  ct_srv_dst  is_sm_ips_ports  attack_cat
# 0                1           2                0      Normal
# 1                1           2                0      Normal
# 2                1           3                0      Normal
# 3                2           3                0      Normal
# 4                2           3                0      Normal
# ...            ...         ...              ...         ...
# 257668          24          24                0     Generic
# 257669           1           1                0   Shellcode
# 257670           3          12                0     Generic
# 257671          30          30                0     Generic
# 257672          30          30                0     Generic
#
# [257673 rows x 44 columns]

# %% [markdown]
# ## Analyze the Distribution of Data Fields

# %%
import seaborn as sns
import matplotlib.pyplot as plt

numeric_columns = dfEDA.select_dtypes(include=['int64', 'float64']).columns
plt.figure(figsize=(20, 10))
ax = sns.boxplot(data=np.log1p(dfEDA[numeric_columns]))
ax.set_xticklabels(ax.get_xticklabels(), rotation=45, ha='right')
plt.title('Boxplot of Data Fields (Log Scale)')
plt.show()

# %% [markdown]
# - Unusual Network Activity: There may be unusual network activity or network attacks, causing some traffic to have unusual packet numbers, data amounts, or durations.
#
# - Large Transactions: Transactions or connections that can take long periods of time or transfer large amounts of data, creating outliers.
#
# - Error Feed: If the data provided from the source is incorrect or contains errors, it may contain unrealistic values, leading to the occurrence of exceptions.
#
# - Cyber Attacks: Cyber attacks can create unusual behavior in data, such as transmitting large amounts of packets or performing unusual transactions.
#
# - Measurement Bias: If the measurement process is inaccurate or has errors, it can lead to outliers in the data.
#
# - System Problems: Problems in the system or network equipment can also cause outliers, due to the inability to accurately measure or record data.

# %% [markdown]
# ## Correlation

# %%
correlation_matrix = dfEDA[numeric_columns].corr()
plt.figure(figsize=(30, 20))
sns.heatmap(correlation_matrix, annot=True, fmt=".2f")
plt.title('Correlation')
plt.show()

# %% [markdown]
# Variables with Strong Positive Relationships:
# - spkts and sbytes have a strong positive relationship with dpkts and dbytes (correlation > 0.95). This may indicate a high correlation between the number of packets and the number of bytes in the packets.
#
# - ct_srv_src has a strong positive relationship with ct_src_ltm, ct_srv_dst, and some other variables.
#
# Variables with Strong Negative Relationships:
# - dttl has a strong negative relationship with sttl (correlation < -0.45). This suggests a contrasting relationship between the Time to Live of the source and destination.
#
# - dload has a strong negative relationship with sload (correlation < -0.35). This indicates an opposing relationship between download and upload loads.
#
# Variables with No Significant Relationships:
# - Some variables have a correlation very close to 0, for example: id, dwin, trans_depth.
#
# General Relationships:
# - Variables related to the number of packets and bytes tend to have a high correlation with each other.
#
# - Time-related variables (e.g., dur, tcprtt, synack, ackdat) do not show strong relationships with other variables.

# %% [markdown]
# Identifying Strong Relationships Between Variable Pairs:
# Positive Relationships:
#
# spkts and sbytes:
#
# - Strong positive correlation (correlation > 0.95).
# - Indicates a close relationship between the number of packets (spkts) and the number of bytes (sbytes).
#
# ct_srv_src and ct_src_ltm:
# - Strong positive correlation (correlation = 0.822486).
# - Suggests a significant relationship between the number of connections with the same service and source address (ct_srv_src) and the number of connections with the same source address (ct_src_ltm).
#
# ct_srv_src and ct_srv_dst:
# - Strong positive correlation.
# - Indicates a close relationship between the number of connections with the same service and source address (ct_srv_src) and the number of connections with the same service and destination address (ct_srv_dst).
#
# Negative Relationships:
# dttl and sttl:
# - Strong negative correlation (correlation < -0.45).
# - Suggests an inverse relationship between the Time to Live of the destination (dttl) and the Time to Live of the source (sttl).
#
# dload and sload:
# - Strong negative correlation (correlation < -0.35).
# - Indicates an opposing relationship between download load (dload) and upload load (sload).

# %% [markdown]
# ## Analysis of Attack Types

# %%
attack_cat_distribution = dfEDA['attack_cat'].value_counts()
plt.figure(figsize=(10, 8))
attack_cat_distribution.plot(kind='barh', color='skyblue')
plt.title('Distribution of Attack Type')
plt.xlabel('Count')
plt.show()

# %% [markdown]
# - Common Attack Types:
# “Normal” dominates the data, suggesting that most communications in the network are legitimate and attack-free.
#
# - Dominant Attack Type:
# "Generic", "Exploits", and "Fuzzers" make up a large number of attack types. This may imply that the system needs to pay special attention to these types of attacks, and security measures can be implemented to prevent them.
# - Critical Attack Type:
# "Worms" are the least numerous, but they can often cause great damage due to their ability to spread quickly. Although small in number, special attention should be paid to this type of attack because of its highly dangerous nature.
# - Specific Classification:
# Classifications such as "DoS", "Reconnaissance", "Analysis", "Backdoor", and "Shellcode" are also represented in the data, creating a need to detect and prevent specific types of attacks.
# - The Importance of Classification:
# Understanding the types of attacks and classifying them helps determine priorities and appropriate security approaches. For example, a system can focus strongly on preventing "Exploits" attacks if they account for a high proportion.

# %% [markdown]
# ### Comparison Between Normal and Attack Data

# %%
variables_to_analyze = ['spkts', 'sbytes', 'dpkts', 'dbytes', 'ct_srv_src', 'ct_srv_dst']

plt.figure(figsize=(12, 8))
for variable in variables_to_analyze:
    plt.figure(figsize=(12, 8))
    sns.boxplot(x='attack_cat', y=variable, data=df)
    plt.title(f'Boxplot of {variable} for Different Attack Categories')
    plt.xticks(rotation=45)
    plt.show()

# %% [markdown]
# - Normal and Attacks Differ in Scale:
#
# Normal data tends to have a larger scale compared to many types of attacks, as shown by fields such as the number of packets (spkts), number of bytes (sbytes), and the number of connections (ct_srv_src and ct_srv_dst).
# - Attacks Usually Have a Smaller Scale:
#
# Attack types such as Reconnaissance, Backdoor, and Analysis typically have lower average values across many numerical fields compared to normal data.
# - Diverse Distribution of Attack Data:
#
# Different attack types exhibit diversity in the average values and distribution of numerical fields. This highlights the distinct characteristics of each attack type.
# - Significant Differences in Key Fields:
#
# Fields such as the number of packets, number of bytes, and number of connections show substantial differences between normal and attack data.
# - In summary, these numerical fields can be utilized to build intrusion detection models based on the differences in features between normal and attack data.

# %% [markdown]
# ## Missing Values

# %%
df.isnull().sum()
# Out:
# id                   0
# dur                  0
# proto                0
# service              0
# state                0
# spkts                0
# dpkts                0
# sbytes               0
# dbytes               0
# rate                 0
# sttl                 0
# dttl                 0
# sload                0
# dload                0
# sloss                0
# dloss                0
# sinpkt               0
# dinpkt               0
# sjit                 0
# djit                 0
# swin                 0
# stcpb                0
# dtcpb                0
# dwin                 0
# tcprtt               0
# synack               0
# ackdat               0
# smean                0
# dmean                0
# trans_depth          0
# response_body_len    0
# ct_srv_src           0
# ct_state_ttl         0
# ct_dst_ltm           0
# ct_src_dport_ltm     0
# ct_dst_sport_ltm     0
# ct_dst_src_ltm       0
# is_ftp_login         0
# ct_ftp_cmd           0
# ct_flw_http_mthd     0
# ct_src_ltm           0
# ct_srv_dst           0
# is_sm_ips_ports      0
# attack_cat           0
# label                0
# dtype: int64

# %%
import missingno
import pandas as pd

# Assuming 'df' is your DataFrame
missingno.matrix(df)
# Out:
# <Axes: >

# %% [markdown]
# Data is clean and there are no missing values.

# %%
df.describe().transpose()
# Out:
#                       count          mean           std   min           25%  \
# id                 257673.0  7.281182e+04  4.892992e+04   1.0  32210.000000
# dur                257673.0  1.246715e+00  5.974305e+00   0.0      0.000008
# spkts              257673.0  1.977714e+01  1.359472e+02   1.0      2.000000
# dpkts              257673.0  1.851470e+01  1.119860e+02   0.0      0.000000
# sbytes             257673.0  8.572952e+03  1.737739e+05  24.0    114.000000
# dbytes             257673.0  1.438729e+04  1.461993e+05   0.0      0.000000
# rate               257673.0  9.125391e+04  1.603446e+05   0.0     30.789277
# sttl               257673.0  1.800009e+02  1.024883e+02   0.0     62.000000
# dttl               257673.0  8.475496e+01  1.127621e+02   0.0      0.000000
# sload              257673.0  7.060869e+07  1.857313e+08   0.0  12318.004880
# dload              257673.0  6.582143e+05  2.412372e+06   0.0      0.000000
# sloss              257673.0  4.889317e+00  6.557495e+01   0.0      0.000000
# dloss              257673.0  6.743691e+00  5.370222e+01   0.0      0.000000
# sinpkt             257673.0  9.123008e+02  6.922153e+03   0.0      0.008000
# dinpkt             257673.0  9.891546e+01  1.094049e+03   0.0      0.000000
# sjit               257673.0  5.419373e+03  4.903450e+04   0.0      0.000000
# djit               257673.0  5.822515e+02  3.930153e+03   0.0      0.000000
# swin               257673.0  1.217537e+02  1.273674e+02   0.0      0.000000
# stcpb              257673.0  1.006120e+09  1.367795e+09   0.0      0.000000
# dtcpb              257673.0  1.002295e+09  1.363877e+09   0.0      0.000000
# dwin               257673.0  1.192546e+02  1.272305e+02   0.0      0.000000
# tcprtt             257673.0  4.603810e-02  9.290834e-02   0.0      0.000000
# synack             257673.0  2.365186e-02  5.385637e-02   0.0      0.000000
# ackdat             257673.0  2.238624e-02  4.577063e-02   0.0      0.000000
# smean              257673.0  1.376390e+02  2.059011e+02  24.0     57.000000
# dmean              257673.0  1.216497e+02  2.540410e+02   0.0      0.000000
# trans_depth        257673.0  1.022420e-01  7.105928e-01   0.0      0.000000
# response_body_len  257673.0  1.968900e+03  4.962523e+04   0.0      0.000000
# ct_srv_src         257673.0  9.383176e+00  1.082971e+01   1.0      2.000000
# ct_state_ttl       257673.0  1.324978e+00  9.922998e-01   0.0      1.000000
# ct_dst_ltm         257673.0  6.050467e+00  8.173749e+00   1.0      1.000000
# ct_src_dport_ltm   257673.0  5.238271e+00  8.160822e+00   1.0      1.000000
# ct_dst_sport_ltm   257673.0  4.032677e+00  5.831515e+00   1.0      1.000000
# ct_dst_src_ltm     257673.0  8.322964e+00  1.112075e+01   1.0      1.000000
# is_ftp_login       257673.0  1.281857e-02  1.160907e-01   0.0      0.000000
# ct_ftp_cmd         257673.0  1.284962e-02  1.164211e-01   0.0      0.000000
# ct_flw_http_mthd   257673.0  1.320045e-01  6.818536e-01   0.0      0.000000
# ct_src_ltm         257673.0  6.800045e+00  8.396266e+00   1.0      2.000000
# ct_srv_dst         257673.0  9.121049e+00  1.087475e+01   1.0      2.000000
# is_sm_ips_ports    257673.0  1.427391e-02  1.186179e-01   0.0      0.000000
# label              257673.0  6.390774e-01  4.802691e-01   0.0      0.000000
#
#                              50%           75%           max
# id                  64419.000000  1.109230e+05  1.753410e+05
# dur                     0.004285  6.857770e-01  5.999999e+01
# spkts                   4.000000  1.200000e+01  1.064600e+04
# dpkts                   2.000000  1.000000e+01  1.101800e+04
# sbytes                528.000000  1.362000e+03  1.435577e+07
# dbytes                178.000000  1.064000e+03  1.465753e+07
# rate                 2955.664893  1.250000e+05  1.000000e+06
# sttl                  254.000000  2.540000e+02  2.550000e+02
# dttl                   29.000000  2.520000e+02  2.540000e+02
# sload              743942.312500  8.000000e+07  5.988000e+09
# dload                1747.441284  2.210538e+04  2.242273e+07
# sloss                   0.000000  3.000000e+00  5.319000e+03
# dloss                   0.000000  2.000000e+00  5.507000e+03
# sinpkt                  0.381696  5.809473e+01  8.437150e+04
# dinpkt                  0.007000  5.643886e+01  5.773924e+04
# sjit                    0.673637  2.787367e+03  1.483831e+06
# djit                    0.000000  1.197129e+02  4.631992e+05
# swin                    0.000000  2.550000e+02  2.550000e+02
# stcpb                   0.000000  2.007375e+09  4.294959e+09
# dtcpb                   0.000000  1.992752e+09  4.294882e+09
# dwin                    0.000000  2.550000e+02  2.550000e+02
# tcprtt                  0.000000  8.208200e-02  3.821465e+00
# synack                  0.000000  3.684200e-02  3.226788e+00
# ackdat                  0.000000  4.466500e-02  2.928778e+00
# smean                  73.000000  1.000000e+02  1.504000e+03
# dmean                  44.000000  8.900000e+01  1.500000e+03
# trans_depth             0.000000  0.000000e+00  1.720000e+02
# response_body_len       0.000000  0.000000e+00  6.558056e+06
# ct_srv_src              5.000000  1.200000e+01  6.300000e+01
# ct_state_ttl            1.000000  2.000000e+00  6.000000e+00
# ct_dst_ltm              2.000000  6.000000e+00  5.900000e+01
# ct_src_dport_ltm        1.000000  4.000000e+00  5.900000e+01
# ct_dst_sport_ltm        1.000000  3.000000e+00  4.600000e+01
# ct_dst_src_ltm          3.000000  8.000000e+00  6.500000e+01
# is_ftp_login            0.000000  0.000000e+00  4.000000e+00
# ct_ftp_cmd              0.000000  0.000000e+00  4.000000e+00
# ct_flw_http_mthd        0.000000  0.000000e+00  3.000000e+01
# ct_src_ltm              3.000000  8.000000e+00  6.000000e+01
# ct_srv_dst              4.000000  1.100000e+01  6.200000e+01
# is_sm_ips_ports         0.000000  0.000000e+00  1.000000e+00
# label                   1.000000  1.000000e+00  1.000000e+00

# %% [markdown]
# ## Insights and steps:
# - Data is clean.
# - Data still needs furthur processing in terms of One-hot-encoding for categorical data. E.g.: 'service' consists of different types, we have ftp, http, and '-' denoting (not available or None), So we will need to treat it as a missing value as we will change it from '-' to 'None' instead of dropping the whole column.
# - Removing unnecessary features like 'id'.

# %%
df['proto'].unique() #This is definitely a categorical feature.
# Out:
# array(['udp', 'arp', 'tcp', 'igmp', 'ospf', 'sctp', 'gre', 'ggp', 'ip',
#        'ipnip', 'st2', 'argus', 'chaos', 'egp', 'emcon', 'nvp', 'pup',
#        'xnet', 'mux', 'dcn', 'hmp', 'prm', 'trunk-1', 'trunk-2',
#        'xns-idp', 'leaf-1', 'leaf-2', 'irtp', 'rdp', 'netblt', 'mfe-nsp',
#        'merit-inp', '3pc', 'idpr', 'ddp', 'idpr-cmtp', 'tp++', 'ipv6',
#        'sdrp', 'ipv6-frag', 'ipv6-route', 'idrp', 'mhrp', 'i-nlsp', 'rvd',
#        'mobile', 'narp', 'skip', 'tlsp', 'ipv6-no', 'any', 'ipv6-opts',
#        'cftp', 'sat-expak', 'ippc', 'kryptolan', 'sat-mon', 'cpnx', 'wsn',
#        'pvp', 'br-sat-mon', 'sun-nd', 'wb-mon', 'vmtp', 'ttp', 'vines',
#        'nsfnet-igp', 'dgp', 'eigrp', 'tcf', 'sprite-rpc', 'larp', 'mtp',
#        'ax.25', 'ipip', 'aes-sp3-d', 'micp', 'encap', 'pri-enc', 'gmtp',
#        'ifmp', 'pnni', 'qnx', 'scps', 'cbt', 'bbn-rcc', 'igp', 'bna',
#        'swipe', 'visa', 'ipcv', 'cphb', 'iso-tp4', 'wb-expak', 'sep',
#        'secure-vmtp', 'xtp', 'il', 'rsvp', 'unas', 'fc', 'iso-ip',
#        'etherip', 'pim', 'aris', 'a/n', 'ipcomp', 'snp', 'compaq-peer',
#        'ipx-n-ip', 'pgm', 'vrrp', 'l2tp', 'zero', 'ddx', 'iatp', 'stp',
#        'srp', 'uti', 'sm', 'smp', 'isis', 'ptp', 'fire', 'crtp', 'crudp',
#        'sccopmce', 'iplt', 'pipe', 'sps', 'ib', 'icmp', 'rtp'],
#       dtype=object)

# %%
df['service'].unique() #Here, we'll deal with the type of service that is '-'
df['service']= np.where(df['service'] == '-', 'None', df['service'])
print(df['service'].unique())
# Out:
# ['None' 'http' 'ftp' 'ftp-data' 'smtp' 'pop3' 'dns' 'snmp' 'ssl' 'dhcp'
#  'irc' 'radius' 'ssh']

# %%
df['state'].unique()
# Out:
# array(['INT', 'FIN', 'REQ', 'ACC', 'CON', 'RST', 'CLO', 'ECO', 'PAR',
#        'URN', 'no'], dtype=object)

# %% [markdown]
# ### Removing unnecessary features

# %%
df = df.drop(['id'], axis=1)

# %%
from sklearn.feature_selection import mutual_info_classif

X = df.select_dtypes(include=['int64', 'float64']).drop('label', axis=1)

y = df['label']

mutual_info = mutual_info_classif(X, y, random_state=42)

mi_scores = pd.Series(mutual_info, index=X.columns, name='Mutual Information Score')
mi_scores = mi_scores.sort_values(ascending=False)
plt.figure(figsize=(12, 15))
plt.barh(mi_scores.index, mi_scores, color='skyblue')
plt.title('Mutual Information Scores for Class Prediction')
plt.xlabel('Mutual Information Score')
plt.ylabel('Features')
plt.show()

# %% [markdown]
# ### Categorical Features:
# One Hot Encoding using cols_cat

# %%
df['attack_cat'].unique() #This is definitely a categorical feature and related to label :) so, we drop it.
# Out:
# array(['Normal', 'Reconnaissance', 'Backdoor', 'DoS', 'Exploits',
#        'Analysis', 'Fuzzers', 'Worms', 'Shellcode', 'Generic'],
#       dtype=object)

# %%
df = df.drop('attack_cat', axis=1)

# %%
"""df_encoded = pd.get_dummies(df, columns=['attack_cat'], prefix='attack_cat', dtype=int)
"""
# Out:
# "df_encoded = pd.get_dummies(df, columns=['attack_cat'], prefix='attack_cat', dtype=int)\n"

# %%
object_columns = df.select_dtypes(include=['object']).columns
object_columns
# Out:
# Index(['proto', 'service', 'state'], dtype='object')

# %%
from sklearn.preprocessing import LabelEncoder
from sklearn.utils import shuffle

shuffled_df = shuffle(df)

label_encoder = LabelEncoder()

shuffled_df['proto'] = label_encoder.fit_transform(shuffled_df['proto'])
shuffled_df['service'] = label_encoder.fit_transform(shuffled_df['service'])
shuffled_df['state'] = label_encoder.fit_transform(shuffled_df['state'])

# %%
shuffled_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 257673 entries, 144154 to 166218
# Data columns (total 43 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   dur                257673 non-null  float64
#  1   proto              257673 non-null  int64
#  2   service            257673 non-null  int64
#  3   state              257673 non-null  int64
#  4   spkts              257673 non-null  int64
#  5   dpkts              257673 non-null  int64
#  6   sbytes             257673 non-null  int64
#  7   dbytes             257673 non-null  int64
#  8   rate               257673 non-null  float64
#  9   sttl               257673 non-null  int64
#  10  dttl               257673 non-null  int64
#  11  sload              257673 non-null  float64
#  12  dload              257673 non-null  float64
#  13  sloss              257673 non-null  int64
#  14  dloss              257673 non-null  int64
#  15  sinpkt             257673 non-null  float64
#  16  dinpkt             257673 non-null  float64
#  17  sjit               257673 non-null  float64
#  18  djit               257673 non-null  float64
#  19  swin               257673 non-null  int64
#  20  stcpb              257673 non-null  int64
#  21  dtcpb              257673 non-null  int64
#  22  dwin               257673 non-null  int64
#  23  tcprtt             257673 non-null  float64
#  24  synack             257673 non-null  float64
#  25  ackdat             257673 non-null  float64
#  26  smean              257673 non-null  int64
#  27  dmean              257673 non-null  int64
#  28  trans_depth        257673 non-null  int64
#  29  response_body_len  257673 non-null  int64
#  30  ct_srv_src         257673 non-null  int64
#  31  ct_state_ttl       257673 non-null  int64
#  32  ct_dst_ltm         257673 non-null  int64
#  33  ct_src_dport_ltm   257673 non-null  int64
#  34  ct_dst_sport_ltm   257673 non-null  int64
#  35  ct_dst_src_ltm     257673 non-null  int64
#  36  is_ftp_login       257673 non-null  int64
#  37  ct_ftp_cmd         257673 non-null  int64
#  38  ct_flw_http_mthd   257673 non-null  int64
#  39  ct_src_ltm         257673 non-null  int64
#  40  ct_srv_dst         257673 non-null  int64
#  41  is_sm_ips_ports    257673 non-null  int64
#  42  label              257673 non-null  int64
# dtypes: float64(11), int64(32)
# memory usage: 86.5 MB

# %% [markdown]
# # Train and Test set splitting

# %%
from sklearn.model_selection import train_test_split

# Define features (X) and target variable (y)
X = shuffled_df.drop(['label'], axis=1)  # Drop the target variable
y = shuffled_df['label']

# Split the data into training, validation, and test sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42, stratify=y)

# Print the shapes of the resulting sets
print("Training set shapes:", X_train.shape, y_train.shape)
print("Test set shapes:", X_test.shape, y_test.shape)
# Out:
# Training set shapes: (180371, 42) (180371,)
# Test set shapes: (77302, 42) (77302,)

# %%
from sklearn import metrics
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression  # New import
from sklearn.neighbors import KNeighborsClassifier  # New import
from sklearn.tree import DecisionTreeClassifier  # New import
from sklearn.metrics import accuracy_score, classification_report
from sklearn.preprocessing import StandardScaler, LabelEncoder, MinMaxScaler, RobustScaler, Normalizer
from sklearn.model_selection import KFold, StratifiedKFold
from tqdm import tqdm_notebook as tqdm
import time

# %%
from sklearn.metrics import f1_score, precision_score, recall_score, accuracy_score
import time

# %%
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2'

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, LSTM, GRU
import keras_metrics as km
import keras
import numpy as np
from numpy import array
# Out:
# 2024-04-09 08:14:57.513624: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-04-09 08:14:57.513749: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-04-09 08:14:57.650004: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered

# %% [markdown]
# # Modelling

# %%
import tensorflow.keras.backend as K

def precision_m(y_true, y_pred):
    true_positives = K.sum(K.round(K.clip(K.cast(y_true, 'float32') * K.cast(y_pred, 'float32'), 0, 1)))
    predicted_positives = K.sum(K.round(K.clip(K.cast(y_pred, 'float32'), 0, 1)))
    precision = true_positives / (predicted_positives + K.epsilon())
    return precision

def recall_m(y_true, y_pred):
    true_positives = K.sum(K.round(K.clip(K.cast(y_true, 'float32') * K.cast(y_pred, 'float32'), 0, 1)))
    possible_positives = K.sum(K.round(K.clip(K.cast(y_true, 'float32'), 0, 1)))
    recall = true_positives / (possible_positives + K.epsilon())
    return recall

def f1_m(y_true, y_pred):
    precision = precision_m(y_true, y_pred)
    recall = recall_m(y_true, y_pred)
    return 2 * ((precision * recall) / (precision + recall + K.epsilon()))

# %%
from sklearn import metrics
from tensorflow.keras.layers import Input
from tensorflow.keras.callbacks import EarlyStopping
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score, classification_report
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, LSTM
from sklearn.utils import class_weight
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
import joblib

def train_random_forest(X_train, y_train, epochs=200):
    # Initialize a Random Forest classifier with the desired number of trees
    clf = RandomForestClassifier(n_estimators=epochs, random_state=42)
    
    # Train the Random Forest classifier
    print("Training Random Forest...")
    clf.fit(X_train, y_train)
    print("Random Forest training completed")
    
    return clf

def evaluate_random_forest(model, X_test, y_test):
    y_test_pred = model.predict(X_test)
    accuracy = accuracy_score(y_test, y_test_pred)
    loss = metrics.log_loss(y_test, y_test_pred)  # Added loss calculation
    report = classification_report(y_test, y_test_pred, output_dict=True)
    precision = report['weighted avg']['precision']
    recall = report['weighted avg']['recall']
    f1_score = report['weighted avg']['f1-score']
    return accuracy, f1_score, precision, recall, loss


def train_mlp(X_train, y_train, epochs=200, batch_size=2000):
    model = Sequential()
    model.add(Input(shape=(X_train.shape[1],)))  # Input layer
    model.add(Dense(20, activation='relu'))
    model.add(Dense(20, activation='relu'))
    model.add(Dense(20, activation='softmax'))
    model.compile(loss='sparse_categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
    model.fit(X_train, y_train, epochs=epochs, batch_size=batch_size, verbose=2)
    return model

def evaluate_mlp(model, X_test, y_test):
    # Evaluate the model
    loss, accuracy = model.evaluate(X_test, y_test, verbose=0)
    
    # Predict probabilities for each class
    y_probs = model.predict(X_test)
    # Convert probabilities to class labels
    y_pred = np.argmax(y_probs, axis=1)
    
    # Calculate precision, recall, and F1 score
    precision = precision_score(y_test, y_pred, average='weighted')
    recall = recall_score(y_test, y_pred, average='weighted')
    f1s = f1_score(y_test, y_pred, average='weighted')
    
    return accuracy, loss, f1s, precision, recall

def train_lstm(X_train, y_train, epochs=200, batch_size=2000):
    model = Sequential()
    model.add(LSTM(20, return_sequences=True, input_shape=(1, X_train.shape[1])))
    model.add(LSTM(20, return_sequences=True))
    model.add(Dense(1, activation='sigmoid'))  # For binary classification
    model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy', f1_m, precision_m, recall_m])

    # Encode binary labels
    label_encoder = LabelEncoder()
    y_train_encoded = label_encoder.fit_transform(y_train)
    y_train_encoded = y_train_encoded.reshape(-1, 1, 1)  # Reshape labels to match the shape of predictions

    X_train_array = np.array(X_train)
    X_train_reshaped = X_train_array.reshape(X_train_array.shape[0], 1, X_train_array.shape[1])

    # Train the model
    model.fit(X_train_reshaped, y_train_encoded, epochs=epochs, batch_size=batch_size, verbose=2)
    return model

def evaluate_lstm(model, X_test, y_test):
    scaler = MinMaxScaler()
    X_test_array = np.array(X_test)
    X_test_reshaped = X_test_array.reshape(X_test_array.shape[0], 1, X_test_array.shape[1])
    
    y_test_array = np.array(y_test)
    y_test_reshaped = y_test_array.reshape(-1, 1, 1)

    loss, accuracy, f1s, precision, recall = model.evaluate(X_test_reshaped, y_test_reshaped)
    
    return accuracy, loss, f1s, precision, recall


def train_logistic_regression(X_train, y_train):
    model = LogisticRegression()
    model.fit(X_train, y_train)
    return model

def evaluate_logistic_regression(model, X_test, y_test):
    y_test_pred = model.predict(X_test)
    accuracy = accuracy_score(y_test, y_test_pred)
    loss = metrics.log_loss(y_test, y_test_pred)  # Added loss calculation
    precision, recall, f1_score = None, None, None
    if len(np.unique(y_test)) > 1:
        report = classification_report(y_test, y_test_pred, output_dict=True)
        precision = report['weighted avg']['precision']
        recall = report['weighted avg']['recall']
        f1_score = report['weighted avg']['f1-score']
    return accuracy, f1_score, precision, recall, loss


def train_knn(X_train, y_train):
    model = KNeighborsClassifier()
    model.fit(X_train, y_train)
    return model

def evaluate_knn(model, X_test, y_test):
    y_test_pred = model.predict(X_test)
    accuracy = accuracy_score(y_test, y_test_pred)
    loss = metrics.log_loss(y_test, y_test_pred)  # Added loss calculation
    precision, recall, f1_score = None, None, None
    if len(np.unique(y_test)) > 1:
        report = classification_report(y_test, y_test_pred, output_dict=True)
        precision = report['weighted avg']['precision']
        recall = report['weighted avg']['recall']
        f1_score = report['weighted avg']['f1-score']
    return accuracy, f1_score, precision, recall, loss

def train_decision_tree(X_train, y_train):
    model = DecisionTreeClassifier()
    model.fit(X_train, y_train)
    return model

def evaluate_decision_tree(model, X_test, y_test):
    y_test_pred = model.predict(X_test)
    accuracy = accuracy_score(y_test, y_test_pred)
    loss = metrics.log_loss(y_test, y_test_pred)  # Added loss calculation
    precision, recall, f1_score = None, None, None
    if len(np.unique(y_test)) > 1:
        report = classification_report(y_test, y_test_pred, output_dict=True)
        precision = report['weighted avg']['precision']
        recall = report['weighted avg']['recall']
        f1_score = report['weighted avg']['f1-score']
    return accuracy, f1_score, precision, recall, loss


def save_model(model, model_name):
    if isinstance(model, (RandomForestClassifier, LogisticRegression, KNeighborsClassifier, DecisionTreeClassifier)):
        joblib.dump(model, f'{model_name}.joblib')
    else:
        model.save(f'{model_name}.h5')
        
def load_model(model_name):
    try:
        model = load_model(f'{model_name}.h5')
    except (OSError, IOError):
        model = joblib.load(f'{model_name}.joblib')
    return model
def train_and_evaluate(X_train, X_test, y_train, y_test, model_type, normalize=False):
    if normalize:
        scaler = MinMaxScaler()
        X_train = scaler.fit_transform(X_train)
        X_test = scaler.transform(X_test)

    if model_type == 'Random Forest':
        model = train_random_forest(X_train, y_train)
        accuracy, f1s, precision, recall, loss = evaluate_random_forest(model, X_test, y_test)
    elif model_type == 'MLP':
        model = train_mlp(X_train, y_train)
        accuracy, loss, f1s, precision, recall = evaluate_mlp(model, X_test, y_test)
    elif model_type == 'LSTM':
        # Reshape input data to have the appropriate shape for LSTM
        X_train_reshaped = X_train.reshape((X_train.shape[0], X_train.shape[1], 1))
        X_test_reshaped = X_test.reshape((X_test.shape[0], X_test.shape[1], 1))
        
        model = train_lstm(X_train_reshaped, y_train)
        accuracy, loss, f1s, precision, recall = evaluate_lstm(model, X_test_reshaped, y_test)
    elif model_type == 'Logistic Regression':
        model = train_logistic_regression(X_train, y_train)
        accuracy, f1s, precision, recall, loss = evaluate_logistic_regression(model, X_test, y_test)
    elif model_type == 'KNN':
        model = train_knn(X_train, y_train)
        accuracy, f1s, precision, recall, loss = evaluate_knn(model, X_test, y_test)
    elif model_type == 'Decision Tree':
        model = train_decision_tree(X_train, y_train)
        accuracy, f1s, precision, recall, loss = evaluate_decision_tree(model, X_test, y_test)
    
    save_model(model, f'{model_type.lower()}_model')
    
    model_performance = {
        'Model': model_type,
        'Accuracy': accuracy,
        'F1 Score' : f1s,
        'Precision': precision,
        'Recall': recall,
        'Loss': loss
    }

    return model_performance

# %%
X_dropped_attack_cat = shuffled_df.drop(['label'], axis=1)
y_dropped_attack_cat = shuffled_df['label']

X_train_dropped_attack_cat, X_test_dropped_attack_cat, y_train_dropped_attack_cat, y_test_dropped_attack_cat = train_test_split(
    X_dropped_attack_cat, y_dropped_attack_cat, test_size=0.3, random_state=42, stratify=y_dropped_attack_cat
)

# %%
import pandas as pd

# Initialize an empty list to store results
results_list = []

# %%
rf_performance_dropped_attack_cat = train_and_evaluate(X_train_dropped_attack_cat, X_test_dropped_attack_cat, y_train_dropped_attack_cat, y_test_dropped_attack_cat, 'Random Forest')
# Out:
# Training Random Forest...
# Random Forest training completed

# %%
mlp_performance_dropped_attack_cat = train_and_evaluate(X_train_dropped_attack_cat, X_test_dropped_attack_cat, y_train_dropped_attack_cat, y_test_dropped_attack_cat, 'MLP', normalize=True)
# Out:
# Epoch 1/200
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1712650586.324114      97 device_compiler.h:186] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# W0000 00:00:1712650586.339334      97 graph_launch.cc:671] Fallback to op-by-op mode because memset node breaks graph update
# 91/91 - 3s - 33ms/step - accuracy: 0.3898 - loss: 2.2126
# Epoch 2/200
# 91/91 - 0s - 2ms/step - accuracy: 0.8388 - loss: 0.4815
# Epoch 3/200
# 91/91 - 0s - 2ms/step - accuracy: 0.8710 - loss: 0.3023
# Epoch 4/200
# 91/91 - 0s - 2ms/step - accuracy: 0.8869 - loss: 0.2533
# Epoch 5/200
# 91/91 - 0s - 2ms/step - accuracy: 0.8902 - loss: 0.2333
# Epoch 6/200
# 91/91 - 0s - 2ms/step - accuracy: 0.8923 - loss: 0.2249
# Epoch 7/200
# 91/91 - 0s - 2ms/step - accuracy: 0.8940 - loss: 0.2198
# Epoch 8/200
# 91/91 - 0s - 2ms/step - accuracy: 0.8955 - loss: 0.2156
# Epoch 9/200
# 91/91 - 0s - 3ms/step - accuracy: 0.8973 - loss: 0.2131
# Epoch 10/200
# 91/91 - 0s - 2ms/step - accuracy: 0.8982 - loss: 0.2104
# Epoch 11/200
# 91/91 - 0s - 2ms/step - accuracy: 0.8997 - loss: 0.2081
# Epoch 12/200
# 91/91 - 0s - 2ms/step - accuracy: 0.9004 - loss: 0.2064
# Epoch 13/200
# 91/91 - 0s - 2ms/step - accuracy: 0.9020 - loss: 0.2037
# Epoch 14/200
# 91/91 - 0s - 2ms/step - accuracy: 0.9029 - loss: 0.2022
# Epoch 15/200
# 91/91 - 0s - 2ms/step - accuracy: 0.9039 - loss: 0.2000
# Epoch 16/200
# 91/91 - 0s - 3ms/step - accuracy: 0.9043 - loss: 0.1975
# Epoch 17/200
# 91/91 - 0s - 2ms/step - accuracy: 0.9051 - loss: 0.1952
# Epoch 18/200
# 91/91 - 0s - 3ms/step - accuracy: 0.9060 - loss: 0.1931
# Epoch 19/200
# 91/91 - 0s - 2ms/step - accuracy: 0.9071 - loss: 0.1916
# Epoch 20/200
# 91/91 - 0s - 2ms/step - accuracy: 0.9076 - loss: 0.1902
# Epoch 21/200
# 91/91 - 0s - 2ms/step - accuracy: 0.9080 - loss: 0.1890
# Epoch 22/200
# 91/91 - 0s - 2ms/step - accuracy: 0.9086 - loss: 0.1874
# Epoch 23/200
# 91/91 - 0s - 2ms/step - accuracy: 0.9093 - loss: 0.1863
# Epoch 24/200
# 91/91 - 0s - 3ms/step - accuracy: 0.9099 - loss: 0.1854
# Epoch 25/200
# 91/91 - 0s - 3ms/step - accuracy: 0.9102 - loss: 0.1844
# Epoch 26/200
# 91/91 - 0s - 3ms/step - accuracy: 0.9106 - loss: 0.1840
# Epoch 27/200
# 91/91 - 0s - 2ms/step - accuracy: 0.9108 - loss: 0.1830
# Epoch 28/200
# 91/91 - 0s - 2ms/step - accuracy: 0.9110 - loss: 0.1822
# Epoch 29/200
# 91/91 - 0s - 2ms/step - accuracy: 0.9114 - loss: 0.1812
# Epoch 30/200
# 91/91 - 0s - 2ms/step - accuracy: 0.9122 - loss: 0.1803
# Epoch 31/200
# 91/91 - 0s - 2ms/step - accuracy: 0.9122 - loss: 0.1800
# Epoch 32/200
# 91/91 - 0s - 2ms/step - accuracy: 0.9125 - loss: 0.1790
# Epoch 33/200
# 91/91 - 0s - 2ms/step - accuracy: 0.9130 - loss: 0.1783
# Epoch 34/200
# 91/91 - 0s - 2ms/step - accuracy: 0.9130 - loss: 0.1775
# Epoch 35/200
# 91/91 - 0s - 2ms/step - accuracy: 0.9133 - loss: 0.1768
# Epoch 36/200
# 91/91 - 0s - 2ms/step - accuracy: 0.9135 - loss: 0.1765
# Epoch 37/200
# 91/91 - 0s - 2ms/step - accuracy: 0.9139 - loss: 0.1761
# Epoch 38/200
# 91/91 - 0s - 2ms/step - accuracy: 0.9140 - loss: 0.1753
# Epoch 39/200
# 91/91 - 0s - 2ms/step - accuracy: 0.9139 - loss: 0.1746
# Epoch 40/200
# 91/91 - 0s - 2ms/step - accuracy: 0.9150 - loss: 0.1733
# Epoch 41/200
# 91/91 - 0s - 2ms/step - accuracy: 0.9149 - loss: 0.1736
# Epoch 42/200
# 91/91 - 0s - 2ms/step - accuracy: 0.9158 - loss: 0.1726
# Epoch 43/200
# 91/91 - 0s - 2ms/step - accuracy: 0.9160 - loss: 0.1720
# Epoch 44/200
# 91/91 - 0s - 2ms/step - accuracy: 0.9163 - loss: 0.1713
# Epoch 45/200
# 91/91 - 0s - 2ms/step - accuracy: 0.9168 - loss: 0.1706
# Epoch 46/200
# 91/91 - 0s - 2ms/step - accuracy: 0.9173 - loss: 0.1702
# Epoch 47/200
# 91/91 - 0s - 2ms/step - accuracy: 0.9176 - loss: 0.1694
# Epoch 48/200
# 91/91 - 0s - 2ms/step - accuracy: 0.9182 - loss: 0.1689
# Epoch 49/200
# 91/91 - 0s - 2ms/step - accuracy: 0.9186 - loss: 0.1684
# Epoch 50/200
# 91/91 - 0s - 2ms/step - accuracy: 0.9187 - loss: 0.1677
# Epoch 51/200
# 91/91 - 0s - 2ms/step - accuracy: 0.9188 - loss: 0.1671
# Epoch 52/200
# 91/91 - 0s - 2ms/step - accuracy: 0.9189 - loss: 0.1672
# Epoch 53/200
# 91/91 - 0s - 2ms/step - accuracy: 0.9197 - loss: 0.1662
# Epoch 54/200
# 91/91 - 0s - 2ms/step - accuracy: 0.9205 - loss: 0.1653
# Epoch 55/200
# 91/91 - 0s - 2ms/step - accuracy: 0.9210 - loss: 0.1647
# Epoch 56/200
# 91/91 - 0s - 2ms/step - accuracy: 0.9215 - loss: 0.1634
# Epoch 57/200
# 91/91 - 0s - 2ms/step - accuracy: 0.9220 - loss: 0.1631
# Epoch 58/200
# 91/91 - 0s - 2ms/step - accuracy: 0.9224 - loss: 0.1625
# Epoch 59/200
# 91/91 - 0s - 2ms/step - accuracy: 0.9233 - loss: 0.1617
# Epoch 60/200
# 91/91 - 0s - 2ms/step - accuracy: 0.9231 - loss: 0.1612
# Epoch 61/200
# 91/91 - 0s - 2ms/step - accuracy: 0.9234 - loss: 0.1610
# Epoch 62/200
# 91/91 - 0s - 2ms/step - accuracy: 0.9238 - loss: 0.1603
# Epoch 63/200
# 91/91 - 0s - 2ms/step - accuracy: 0.9233 - loss: 0.1604
# Epoch 64/200
# 91/91 - 0s - 2ms/step - accuracy: 0.9242 - loss: 0.1599
# Epoch 65/200
# 91/91 - 0s - 2ms/step - accuracy: 0.9244 - loss: 0.1587
# Epoch 66/200
# 91/91 - 0s - 2ms/step - accuracy: 0.9248 - loss: 0.1585
# Epoch 67/200
# 91/91 - 0s - 2ms/step - accuracy: 0.9251 - loss: 0.1585
# Epoch 68/200
# 91/91 - 0s - 2ms/step - accuracy: 0.9252 - loss: 0.1574
# Epoch 69/200
# 91/91 - 0s - 2ms/step - accuracy: 0.9255 - loss: 0.1569
# Epoch 70/200
# 91/91 - 0s - 2ms/step - accuracy: 0.9258 - loss: 0.1565
# Epoch 71/200
# 91/91 - 0s - 2ms/step - accuracy: 0.9268 - loss: 0.1558
# Epoch 72/200
# 91/91 - 0s - 2ms/step - accuracy: 0.9264 - loss: 0.1555
# Epoch 73/200
# 91/91 - 0s - 2ms/step - accuracy: 0.9264 - loss: 0.1561
# Epoch 74/200
# 91/91 - 0s - 2ms/step - accuracy: 0.9265 - loss: 0.1551
# Epoch 75/200
# 91/91 - 0s - 2ms/step - accuracy: 0.9271 - loss: 0.1552
# Epoch 76/200
# 91/91 - 0s - 2ms/step - accuracy: 0.9267 - loss: 0.1542
# Epoch 77/200
# 91/91 - 0s - 2ms/step - accuracy: 0.9278 - loss: 0.1544
# Epoch 78/200
# 91/91 - 0s - 2ms/step - accuracy: 0.9272 - loss: 0.1543
# Epoch 79/200
# 91/91 - 0s - 2ms/step - accuracy: 0.9275 - loss: 0.1543
# Epoch 80/200
# 91/91 - 0s - 2ms/step - accuracy: 0.9273 - loss: 0.1539
# Epoch 81/200
# 91/91 - 0s - 2ms/step - accuracy: 0.9277 - loss: 0.1531
# Epoch 82/200
# 91/91 - 0s - 2ms/step - accuracy: 0.9279 - loss: 0.1535
# Epoch 83/200
# 91/91 - 0s - 2ms/step - accuracy: 0.9277 - loss: 0.1537
# Epoch 84/200
# 91/91 - 0s - 2ms/step - accuracy: 0.9281 - loss: 0.1529
# Epoch 85/200
# 91/91 - 0s - 2ms/step - accuracy: 0.9283 - loss: 0.1529
# Epoch 86/200
# 91/91 - 0s - 2ms/step - accuracy: 0.9286 - loss: 0.1527
# Epoch 87/200
# 91/91 - 0s - 2ms/step - accuracy: 0.9287 - loss: 0.1523
# Epoch 88/200
# 91/91 - 0s - 2ms/step - accuracy: 0.9287 - loss: 0.1527
# Epoch 89/200
# 91/91 - 0s - 2ms/step - accuracy: 0.9292 - loss: 0.1523
# Epoch 90/200
# 91/91 - 0s - 3ms/step - accuracy: 0.9289 - loss: 0.1521
# Epoch 91/200
# 91/91 - 0s - 2ms/step - accuracy: 0.9298 - loss: 0.1514
# Epoch 92/200
# 91/91 - 0s - 2ms/step - accuracy: 0.9293 - loss: 0.1517
# Epoch 93/200
# 91/91 - 0s - 2ms/step - accuracy: 0.9294 - loss: 0.1514
# Epoch 94/200
# 91/91 - 0s - 2ms/step - accuracy: 0.9287 - loss: 0.1515
# Epoch 95/200
# 91/91 - 0s - 2ms/step - accuracy: 0.9295 - loss: 0.1514
# Epoch 96/200
# 91/91 - 0s - 2ms/step - accuracy: 0.9292 - loss: 0.1507
# Epoch 97/200
# 91/91 - 0s - 2ms/step - accuracy: 0.9293 - loss: 0.1515
# Epoch 98/200
# 91/91 - 0s - 2ms/step - accuracy: 0.9296 - loss: 0.1508
# Epoch 99/200
# 91/91 - 0s - 2ms/step - accuracy: 0.9294 - loss: 0.1510
# Epoch 100/200
# 91/91 - 0s - 2ms/step - accuracy: 0.9296 - loss: 0.1511
# Epoch 101/200
# 91/91 - 0s - 2ms/step - accuracy: 0.9292 - loss: 0.1510
# Epoch 102/200
# 91/91 - 0s - 2ms/step - accuracy: 0.9299 - loss: 0.1502
# Epoch 103/200
# 91/91 - 0s - 2ms/step - accuracy: 0.9300 - loss: 0.1502
# Epoch 104/200
# 91/91 - 0s - 2ms/step - accuracy: 0.9296 - loss: 0.1507
# Epoch 105/200
# 91/91 - 0s - 2ms/step - accuracy: 0.9300 - loss: 0.1498
# Epoch 106/200
# 91/91 - 0s - 2ms/step - accuracy: 0.9300 - loss: 0.1496
# Epoch 107/200
# 91/91 - 0s - 2ms/step - accuracy: 0.9304 - loss: 0.1496
# Epoch 108/200
# 91/91 - 0s - 2ms/step - accuracy: 0.9291 - loss: 0.1502
# Epoch 109/200
# 91/91 - 0s - 2ms/step - accuracy: 0.9301 - loss: 0.1494
# Epoch 110/200
# 91/91 - 0s - 2ms/step - accuracy: 0.9303 - loss: 0.1494
# Epoch 111/200
# 91/91 - 0s - 2ms/step - accuracy: 0.9299 - loss: 0.1496
# Epoch 112/200
# 91/91 - 0s - 2ms/step - accuracy: 0.9303 - loss: 0.1493
# Epoch 113/200
# 91/91 - 0s - 2ms/step - accuracy: 0.9307 - loss: 0.1493
# Epoch 114/200
# 91/91 - 0s - 2ms/step - accuracy: 0.9303 - loss: 0.1492
# Epoch 115/200
# 91/91 - 0s - 2ms/step - accuracy: 0.9305 - loss: 0.1491
# Epoch 116/200
# 91/91 - 0s - 2ms/step - accuracy: 0.9306 - loss: 0.1489
# Epoch 117/200
# 91/91 - 0s - 2ms/step - accuracy: 0.9289 - loss: 0.1499
# Epoch 118/200
# 91/91 - 0s - 2ms/step - accuracy: 0.9304 - loss: 0.1490
# Epoch 119/200
# 91/91 - 0s - 2ms/step - accuracy: 0.9298 - loss: 0.1494
# Epoch 120/200
# 91/91 - 0s - 2ms/step - accuracy: 0.9304 - loss: 0.1483
# Epoch 121/200
# 91/91 - 0s - 2ms/step - accuracy: 0.9305 - loss: 0.1488
# Epoch 122/200
# 91/91 - 0s - 2ms/step - accuracy: 0.9305 - loss: 0.1487
# Epoch 123/200
# 91/91 - 0s - 2ms/step - accuracy: 0.9302 - loss: 0.1491
# Epoch 124/200
# 91/91 - 0s - 2ms/step - accuracy: 0.9304 - loss: 0.1486
# Epoch 125/200
# 91/91 - 0s - 2ms/step - accuracy: 0.9309 - loss: 0.1483
# Epoch 126/200
# 91/91 - 0s - 2ms/step - accuracy: 0.9310 - loss: 0.1482
# Epoch 127/200
# 91/91 - 0s - 2ms/step - accuracy: 0.9309 - loss: 0.1477
# Epoch 128/200
# 91/91 - 0s - 2ms/step - accuracy: 0.9310 - loss: 0.1484
# Epoch 129/200
# 91/91 - 0s - 2ms/step - accuracy: 0.9308 - loss: 0.1475
# Epoch 130/200
# 91/91 - 0s - 2ms/step - accuracy: 0.9306 - loss: 0.1478
# Epoch 131/200
# 91/91 - 0s - 2ms/step - accuracy: 0.9310 - loss: 0.1476
# Epoch 132/200
# 91/91 - 0s - 2ms/step - accuracy: 0.9310 - loss: 0.1479
# Epoch 133/200
# 91/91 - 0s - 2ms/step - accuracy: 0.9302 - loss: 0.1480
# Epoch 134/200
# 91/91 - 0s - 2ms/step - accuracy: 0.9309 - loss: 0.1472
# Epoch 135/200
# 91/91 - 0s - 2ms/step - accuracy: 0.9313 - loss: 0.1472
# Epoch 136/200
# 91/91 - 0s - 2ms/step - accuracy: 0.9311 - loss: 0.1472
# Epoch 137/200
# 91/91 - 0s - 2ms/step - accuracy: 0.9313 - loss: 0.1468
# Epoch 138/200
# 91/91 - 0s - 2ms/step - accuracy: 0.9311 - loss: 0.1469
# Epoch 139/200
# 91/91 - 0s - 2ms/step - accuracy: 0.9311 - loss: 0.1468
# Epoch 140/200
# 91/91 - 0s - 2ms/step - accuracy: 0.9315 - loss: 0.1466
# Epoch 141/200
# 91/91 - 0s - 2ms/step - accuracy: 0.9314 - loss: 0.1465
# Epoch 142/200
# 91/91 - 0s - 2ms/step - accuracy: 0.9314 - loss: 0.1466
# Epoch 143/200
# 91/91 - 0s - 2ms/step - accuracy: 0.9306 - loss: 0.1469
# Epoch 144/200
# 91/91 - 0s - 2ms/step - accuracy: 0.9315 - loss: 0.1463
# Epoch 145/200
# 91/91 - 0s - 2ms/step - accuracy: 0.9313 - loss: 0.1468
# Epoch 146/200
# 91/91 - 0s - 2ms/step - accuracy: 0.9309 - loss: 0.1461
# Epoch 147/200
# 91/91 - 0s - 2ms/step - accuracy: 0.9304 - loss: 0.1469
# Epoch 148/200
# 91/91 - 0s - 2ms/step - accuracy: 0.9311 - loss: 0.1461
# Epoch 149/200
# 91/91 - 0s - 2ms/step - accuracy: 0.9315 - loss: 0.1460
# Epoch 150/200
# 91/91 - 0s - 2ms/step - accuracy: 0.9313 - loss: 0.1461
# Epoch 151/200
# 91/91 - 0s - 2ms/step - accuracy: 0.9314 - loss: 0.1462
# Epoch 152/200
# 91/91 - 0s - 2ms/step - accuracy: 0.9312 - loss: 0.1460
# Epoch 153/200
# 91/91 - 0s - 2ms/step - accuracy: 0.9311 - loss: 0.1459
# Epoch 154/200
# 91/91 - 0s - 2ms/step - accuracy: 0.9315 - loss: 0.1456
# Epoch 155/200
# 91/91 - 0s - 2ms/step - accuracy: 0.9316 - loss: 0.1459
# Epoch 156/200
# 91/91 - 0s - 2ms/step - accuracy: 0.9314 - loss: 0.1455
# Epoch 157/200
# 91/91 - 0s - 2ms/step - accuracy: 0.9316 - loss: 0.1453
# Epoch 158/200
# 91/91 - 0s - 2ms/step - accuracy: 0.9318 - loss: 0.1452
# Epoch 159/200
# 91/91 - 0s - 2ms/step - accuracy: 0.9318 - loss: 0.1452
# Epoch 160/200
# 91/91 - 0s - 2ms/step - accuracy: 0.9318 - loss: 0.1452
# Epoch 161/200
# 91/91 - 0s - 2ms/step - accuracy: 0.9314 - loss: 0.1454
# Epoch 162/200
# 91/91 - 0s - 2ms/step - accuracy: 0.9316 - loss: 0.1457
# Epoch 163/200
# 91/91 - 0s - 2ms/step - accuracy: 0.9315 - loss: 0.1455
# Epoch 164/200
# 91/91 - 0s - 2ms/step - accuracy: 0.9320 - loss: 0.1450
# Epoch 165/200
# 91/91 - 0s - 2ms/step - accuracy: 0.9318 - loss: 0.1446
# Epoch 166/200
# 91/91 - 0s - 2ms/step - accuracy: 0.9315 - loss: 0.1451
# Epoch 167/200
# 91/91 - 0s - 2ms/step - accuracy: 0.9318 - loss: 0.1451
# Epoch 168/200
# 91/91 - 0s - 3ms/step - accuracy: 0.9314 - loss: 0.1452
# Epoch 169/200
# 91/91 - 0s - 2ms/step - accuracy: 0.9316 - loss: 0.1446
# Epoch 170/200
# 91/91 - 0s - 2ms/step - accuracy: 0.9314 - loss: 0.1444
# Epoch 171/200
# 91/91 - 0s - 2ms/step - accuracy: 0.9319 - loss: 0.1451
# Epoch 172/200
# 91/91 - 0s - 2ms/step - accuracy: 0.9314 - loss: 0.1446
# Epoch 173/200
# 91/91 - 0s - 2ms/step - accuracy: 0.9319 - loss: 0.1445
# Epoch 174/200
# 91/91 - 0s - 2ms/step - accuracy: 0.9319 - loss: 0.1439
# Epoch 175/200
# 91/91 - 0s - 2ms/step - accuracy: 0.9315 - loss: 0.1446
# Epoch 176/200
# 91/91 - 0s - 2ms/step - accuracy: 0.9319 - loss: 0.1445
# Epoch 177/200
# 91/91 - 0s - 2ms/step - accuracy: 0.9316 - loss: 0.1442
# Epoch 178/200
# 91/91 - 0s - 2ms/step - accuracy: 0.9316 - loss: 0.1440
# Epoch 179/200
# 91/91 - 0s - 2ms/step - accuracy: 0.9317 - loss: 0.1447
# Epoch 180/200
# 91/91 - 0s - 2ms/step - accuracy: 0.9317 - loss: 0.1445
# Epoch 181/200
# 91/91 - 0s - 2ms/step - accuracy: 0.9314 - loss: 0.1443
# Epoch 182/200
# 91/91 - 0s - 2ms/step - accuracy: 0.9317 - loss: 0.1442
# Epoch 183/200
# 91/91 - 0s - 2ms/step - accuracy: 0.9321 - loss: 0.1436
# Epoch 184/200
# 91/91 - 0s - 2ms/step - accuracy: 0.9318 - loss: 0.1438
# Epoch 185/200
# 91/91 - 0s - 2ms/step - accuracy: 0.9317 - loss: 0.1440
# Epoch 186/200
# 91/91 - 0s - 2ms/step - accuracy: 0.9318 - loss: 0.1434
# Epoch 187/200
# 91/91 - 0s - 2ms/step - accuracy: 0.9316 - loss: 0.1436
# Epoch 188/200
# 91/91 - 0s - 2ms/step - accuracy: 0.9310 - loss: 0.1441
# Epoch 189/200
# 91/91 - 0s - 2ms/step - accuracy: 0.9320 - loss: 0.1436
# Epoch 190/200
# 91/91 - 0s - 2ms/step - accuracy: 0.9318 - loss: 0.1432
# Epoch 191/200
# 91/91 - 0s - 2ms/step - accuracy: 0.9317 - loss: 0.1431
# Epoch 192/200
# 91/91 - 0s - 2ms/step - accuracy: 0.9320 - loss: 0.1434
# Epoch 193/200
# 91/91 - 0s - 2ms/step - accuracy: 0.9318 - loss: 0.1435
# Epoch 194/200
# 91/91 - 0s - 2ms/step - accuracy: 0.9314 - loss: 0.1435
# Epoch 195/200
# 91/91 - 0s - 2ms/step - accuracy: 0.9320 - loss: 0.1429
# Epoch 196/200
# 91/91 - 0s - 4ms/step - accuracy: 0.9317 - loss: 0.1434
# Epoch 197/200
# 91/91 - 0s - 3ms/step - accuracy: 0.9320 - loss: 0.1432
# Epoch 198/200
# 91/91 - 0s - 3ms/step - accuracy: 0.9323 - loss: 0.1432
# Epoch 199/200
# 91/91 - 0s - 2ms/step - accuracy: 0.9323 - loss: 0.1430
# Epoch 200/200
# 91/91 - 0s - 2ms/step - accuracy: 0.9311 - loss: 0.1437
# 2416/2416 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step

# %%
lstm_performance_dropped_attack_cat = train_and_evaluate(X_train_dropped_attack_cat, X_test_dropped_attack_cat, y_train_dropped_attack_cat, y_test_dropped_attack_cat, 'LSTM', normalize=True)
# Out:
# /opt/conda/lib/python3.10/site-packages/keras/src/layers/rnn/rnn.py:205: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1/200
# 91/91 - 4s - 44ms/step - accuracy: 0.6587 - f1_m: 0.7840 - loss: 0.6287 - precision_m: 0.6619 - recall_m: 0.9806
# Epoch 2/200
# 91/91 - 0s - 5ms/step - accuracy: 0.7898 - f1_m: 0.8550 - loss: 0.4492 - precision_m: 0.7661 - recall_m: 0.9678
# Epoch 3/200
# 91/91 - 0s - 5ms/step - accuracy: 0.8721 - f1_m: 0.9069 - loss: 0.3097 - precision_m: 0.8492 - recall_m: 0.9732
# Epoch 4/200
# 91/91 - 0s - 5ms/step - accuracy: 0.8875 - f1_m: 0.9168 - loss: 0.2473 - precision_m: 0.8692 - recall_m: 0.9700
# Epoch 5/200
# 91/91 - 0s - 5ms/step - accuracy: 0.8917 - f1_m: 0.9193 - loss: 0.2274 - precision_m: 0.8755 - recall_m: 0.9680
# Epoch 6/200
# 91/91 - 0s - 5ms/step - accuracy: 0.8953 - f1_m: 0.9217 - loss: 0.2168 - precision_m: 0.8823 - recall_m: 0.9650
# Epoch 7/200
# 91/91 - 0s - 5ms/step - accuracy: 0.8971 - f1_m: 0.9228 - loss: 0.2110 - precision_m: 0.8863 - recall_m: 0.9625
# Epoch 8/200
# 91/91 - 0s - 5ms/step - accuracy: 0.8992 - f1_m: 0.9241 - loss: 0.2069 - precision_m: 0.8899 - recall_m: 0.9613
# Epoch 9/200
# 91/91 - 0s - 5ms/step - accuracy: 0.9008 - f1_m: 0.9253 - loss: 0.2039 - precision_m: 0.8920 - recall_m: 0.9614
# Epoch 10/200
# 91/91 - 0s - 5ms/step - accuracy: 0.9019 - f1_m: 0.9260 - loss: 0.2012 - precision_m: 0.8935 - recall_m: 0.9611
# Epoch 11/200
# 91/91 - 0s - 5ms/step - accuracy: 0.9026 - f1_m: 0.9264 - loss: 0.1999 - precision_m: 0.8952 - recall_m: 0.9601
# Epoch 12/200
# 91/91 - 0s - 5ms/step - accuracy: 0.9030 - f1_m: 0.9269 - loss: 0.1980 - precision_m: 0.8961 - recall_m: 0.9600
# Epoch 13/200
# 91/91 - 0s - 5ms/step - accuracy: 0.9037 - f1_m: 0.9272 - loss: 0.1965 - precision_m: 0.8972 - recall_m: 0.9596
# Epoch 14/200
# 91/91 - 1s - 7ms/step - accuracy: 0.9049 - f1_m: 0.9280 - loss: 0.1943 - precision_m: 0.8972 - recall_m: 0.9612
# Epoch 15/200
# 91/91 - 0s - 5ms/step - accuracy: 0.9054 - f1_m: 0.9283 - loss: 0.1931 - precision_m: 0.8986 - recall_m: 0.9603
# Epoch 16/200
# 91/91 - 0s - 5ms/step - accuracy: 0.9061 - f1_m: 0.9290 - loss: 0.1912 - precision_m: 0.8996 - recall_m: 0.9604
# Epoch 17/200
# 91/91 - 0s - 5ms/step - accuracy: 0.9071 - f1_m: 0.9297 - loss: 0.1899 - precision_m: 0.9004 - recall_m: 0.9612
# Epoch 18/200
# 91/91 - 0s - 5ms/step - accuracy: 0.9075 - f1_m: 0.9300 - loss: 0.1884 - precision_m: 0.9011 - recall_m: 0.9608
# Epoch 19/200
# 91/91 - 0s - 5ms/step - accuracy: 0.9077 - f1_m: 0.9301 - loss: 0.1874 - precision_m: 0.9018 - recall_m: 0.9605
# Epoch 20/200
# 91/91 - 0s - 5ms/step - accuracy: 0.9080 - f1_m: 0.9303 - loss: 0.1866 - precision_m: 0.9023 - recall_m: 0.9602
# Epoch 21/200
# 91/91 - 0s - 5ms/step - accuracy: 0.9083 - f1_m: 0.9305 - loss: 0.1860 - precision_m: 0.9029 - recall_m: 0.9601
# Epoch 22/200
# 91/91 - 0s - 4ms/step - accuracy: 0.9092 - f1_m: 0.9309 - loss: 0.1854 - precision_m: 0.9036 - recall_m: 0.9602
# Epoch 23/200
# 91/91 - 0s - 5ms/step - accuracy: 0.9094 - f1_m: 0.9312 - loss: 0.1840 - precision_m: 0.9041 - recall_m: 0.9601
# Epoch 24/200
# 91/91 - 0s - 5ms/step - accuracy: 0.9099 - f1_m: 0.9316 - loss: 0.1834 - precision_m: 0.9054 - recall_m: 0.9596
# Epoch 25/200
# 91/91 - 0s - 5ms/step - accuracy: 0.9103 - f1_m: 0.9318 - loss: 0.1828 - precision_m: 0.9063 - recall_m: 0.9592
# Epoch 26/200
# 91/91 - 0s - 5ms/step - accuracy: 0.9108 - f1_m: 0.9322 - loss: 0.1818 - precision_m: 0.9057 - recall_m: 0.9603
# Epoch 27/200
# 91/91 - 0s - 5ms/step - accuracy: 0.9106 - f1_m: 0.9320 - loss: 0.1812 - precision_m: 0.9058 - recall_m: 0.9599
# Epoch 28/200
# 91/91 - 0s - 5ms/step - accuracy: 0.9111 - f1_m: 0.9323 - loss: 0.1806 - precision_m: 0.9070 - recall_m: 0.9593
# Epoch 29/200
# 91/91 - 0s - 5ms/step - accuracy: 0.9115 - f1_m: 0.9328 - loss: 0.1804 - precision_m: 0.9076 - recall_m: 0.9596
# Epoch 30/200
# 91/91 - 0s - 5ms/step - accuracy: 0.9114 - f1_m: 0.9327 - loss: 0.1800 - precision_m: 0.9080 - recall_m: 0.9591
# Epoch 31/200
# 91/91 - 0s - 5ms/step - accuracy: 0.9117 - f1_m: 0.9327 - loss: 0.1795 - precision_m: 0.9073 - recall_m: 0.9598
# Epoch 32/200
# 91/91 - 0s - 5ms/step - accuracy: 0.9123 - f1_m: 0.9330 - loss: 0.1789 - precision_m: 0.9084 - recall_m: 0.9591
# Epoch 33/200
# 91/91 - 0s - 5ms/step - accuracy: 0.9123 - f1_m: 0.9332 - loss: 0.1783 - precision_m: 0.9086 - recall_m: 0.9593
# Epoch 34/200
# 91/91 - 0s - 5ms/step - accuracy: 0.9129 - f1_m: 0.9337 - loss: 0.1779 - precision_m: 0.9097 - recall_m: 0.9591
# Epoch 35/200
# 91/91 - 0s - 5ms/step - accuracy: 0.9131 - f1_m: 0.9340 - loss: 0.1773 - precision_m: 0.9096 - recall_m: 0.9599
# Epoch 36/200
# 91/91 - 0s - 5ms/step - accuracy: 0.9134 - f1_m: 0.9342 - loss: 0.1770 - precision_m: 0.9101 - recall_m: 0.9597
# Epoch 37/200
# 91/91 - 0s - 5ms/step - accuracy: 0.9135 - f1_m: 0.9339 - loss: 0.1769 - precision_m: 0.9102 - recall_m: 0.9590
# Epoch 38/200
# 91/91 - 0s - 5ms/step - accuracy: 0.9140 - f1_m: 0.9344 - loss: 0.1763 - precision_m: 0.9106 - recall_m: 0.9597
# Epoch 39/200
# 91/91 - 0s - 5ms/step - accuracy: 0.9144 - f1_m: 0.9347 - loss: 0.1759 - precision_m: 0.9115 - recall_m: 0.9592
# Epoch 40/200
# 91/91 - 0s - 5ms/step - accuracy: 0.9141 - f1_m: 0.9343 - loss: 0.1768 - precision_m: 0.9117 - recall_m: 0.9584
# Epoch 41/200
# 91/91 - 0s - 5ms/step - accuracy: 0.9144 - f1_m: 0.9347 - loss: 0.1748 - precision_m: 0.9117 - recall_m: 0.9590
# Epoch 42/200
# 91/91 - 0s - 5ms/step - accuracy: 0.9149 - f1_m: 0.9350 - loss: 0.1748 - precision_m: 0.9125 - recall_m: 0.9589
# Epoch 43/200
# 91/91 - 0s - 5ms/step - accuracy: 0.9149 - f1_m: 0.9351 - loss: 0.1748 - precision_m: 0.9132 - recall_m: 0.9585
# Epoch 44/200
# 91/91 - 1s - 6ms/step - accuracy: 0.9153 - f1_m: 0.9353 - loss: 0.1737 - precision_m: 0.9130 - recall_m: 0.9589
# Epoch 45/200
# 91/91 - 0s - 5ms/step - accuracy: 0.9156 - f1_m: 0.9355 - loss: 0.1733 - precision_m: 0.9133 - recall_m: 0.9589
# Epoch 46/200
# 91/91 - 0s - 5ms/step - accuracy: 0.9157 - f1_m: 0.9357 - loss: 0.1730 - precision_m: 0.9147 - recall_m: 0.9581
# Epoch 47/200
# 91/91 - 0s - 5ms/step - accuracy: 0.9158 - f1_m: 0.9357 - loss: 0.1733 - precision_m: 0.9146 - recall_m: 0.9581
# Epoch 48/200
# 91/91 - 0s - 5ms/step - accuracy: 0.9162 - f1_m: 0.9358 - loss: 0.1725 - precision_m: 0.9151 - recall_m: 0.9578
# Epoch 49/200
# 91/91 - 0s - 5ms/step - accuracy: 0.9168 - f1_m: 0.9364 - loss: 0.1720 - precision_m: 0.9155 - recall_m: 0.9584
# Epoch 50/200
# 91/91 - 0s - 5ms/step - accuracy: 0.9169 - f1_m: 0.9366 - loss: 0.1715 - precision_m: 0.9161 - recall_m: 0.9581
# Epoch 51/200
# 91/91 - 0s - 5ms/step - accuracy: 0.9172 - f1_m: 0.9366 - loss: 0.1723 - precision_m: 0.9158 - recall_m: 0.9587
# Epoch 52/200
# 91/91 - 0s - 4ms/step - accuracy: 0.9176 - f1_m: 0.9369 - loss: 0.1718 - precision_m: 0.9173 - recall_m: 0.9577
# Epoch 53/200
# 91/91 - 0s - 5ms/step - accuracy: 0.9178 - f1_m: 0.9370 - loss: 0.1713 - precision_m: 0.9173 - recall_m: 0.9577
# Epoch 54/200
# 91/91 - 0s - 5ms/step - accuracy: 0.9180 - f1_m: 0.9373 - loss: 0.1710 - precision_m: 0.9178 - recall_m: 0.9578
# Epoch 55/200
# 91/91 - 0s - 5ms/step - accuracy: 0.9176 - f1_m: 0.9369 - loss: 0.1707 - precision_m: 0.9170 - recall_m: 0.9579
# Epoch 56/200
# 91/91 - 0s - 5ms/step - accuracy: 0.9183 - f1_m: 0.9375 - loss: 0.1700 - precision_m: 0.9186 - recall_m: 0.9574
# Epoch 57/200
# 91/91 - 0s - 5ms/step - accuracy: 0.9181 - f1_m: 0.9373 - loss: 0.1700 - precision_m: 0.9180 - recall_m: 0.9577
# Epoch 58/200
# 91/91 - 0s - 5ms/step - accuracy: 0.9184 - f1_m: 0.9374 - loss: 0.1695 - precision_m: 0.9186 - recall_m: 0.9572
# Epoch 59/200
# 91/91 - 0s - 5ms/step - accuracy: 0.9189 - f1_m: 0.9379 - loss: 0.1693 - precision_m: 0.9191 - recall_m: 0.9576
# Epoch 60/200
# 91/91 - 0s - 5ms/step - accuracy: 0.9189 - f1_m: 0.9378 - loss: 0.1692 - precision_m: 0.9195 - recall_m: 0.9571
# Epoch 61/200
# 91/91 - 0s - 5ms/step - accuracy: 0.9194 - f1_m: 0.9381 - loss: 0.1688 - precision_m: 0.9200 - recall_m: 0.9572
# Epoch 62/200
# 91/91 - 0s - 5ms/step - accuracy: 0.9194 - f1_m: 0.9382 - loss: 0.1686 - precision_m: 0.9197 - recall_m: 0.9577
# Epoch 63/200
# 91/91 - 0s - 5ms/step - accuracy: 0.9197 - f1_m: 0.9384 - loss: 0.1681 - precision_m: 0.9205 - recall_m: 0.9571
# Epoch 64/200
# 91/91 - 0s - 5ms/step - accuracy: 0.9195 - f1_m: 0.9381 - loss: 0.1688 - precision_m: 0.9208 - recall_m: 0.9562
# Epoch 65/200
# 91/91 - 1s - 7ms/step - accuracy: 0.9197 - f1_m: 0.9382 - loss: 0.1681 - precision_m: 0.9207 - recall_m: 0.9566
# Epoch 66/200
# 91/91 - 0s - 5ms/step - accuracy: 0.9191 - f1_m: 0.9379 - loss: 0.1698 - precision_m: 0.9206 - recall_m: 0.9564
# Epoch 67/200
# 91/91 - 0s - 5ms/step - accuracy: 0.9201 - f1_m: 0.9387 - loss: 0.1674 - precision_m: 0.9212 - recall_m: 0.9570
# Epoch 68/200
# 91/91 - 0s - 5ms/step - accuracy: 0.9199 - f1_m: 0.9383 - loss: 0.1684 - precision_m: 0.9215 - recall_m: 0.9561
# Epoch 69/200
# 91/91 - 0s - 5ms/step - accuracy: 0.9201 - f1_m: 0.9387 - loss: 0.1678 - precision_m: 0.9210 - recall_m: 0.9573
# Epoch 70/200
# 91/91 - 0s - 5ms/step - accuracy: 0.9205 - f1_m: 0.9391 - loss: 0.1669 - precision_m: 0.9224 - recall_m: 0.9566
# Epoch 71/200
# 91/91 - 0s - 5ms/step - accuracy: 0.9210 - f1_m: 0.9392 - loss: 0.1668 - precision_m: 0.9222 - recall_m: 0.9571
# Epoch 72/200
# 91/91 - 0s - 5ms/step - accuracy: 0.9207 - f1_m: 0.9390 - loss: 0.1671 - precision_m: 0.9221 - recall_m: 0.9568
# Epoch 73/200
# 91/91 - 0s - 5ms/step - accuracy: 0.9209 - f1_m: 0.9393 - loss: 0.1664 - precision_m: 0.9222 - recall_m: 0.9571
# Epoch 74/200
# 91/91 - 0s - 5ms/step - accuracy: 0.9213 - f1_m: 0.9395 - loss: 0.1661 - precision_m: 0.9233 - recall_m: 0.9565
# Epoch 75/200
# 91/91 - 1s - 7ms/step - accuracy: 0.9213 - f1_m: 0.9394 - loss: 0.1660 - precision_m: 0.9225 - recall_m: 0.9571
# Epoch 76/200
# 91/91 - 0s - 5ms/step - accuracy: 0.9213 - f1_m: 0.9396 - loss: 0.1661 - precision_m: 0.9235 - recall_m: 0.9567
# Epoch 77/200
# 91/91 - 0s - 5ms/step - accuracy: 0.9217 - f1_m: 0.9397 - loss: 0.1656 - precision_m: 0.9232 - recall_m: 0.9569
# Epoch 78/200
# 91/91 - 0s - 5ms/step - accuracy: 0.9218 - f1_m: 0.9400 - loss: 0.1656 - precision_m: 0.9240 - recall_m: 0.9566
# Epoch 79/200
# 91/91 - 0s - 5ms/step - accuracy: 0.9224 - f1_m: 0.9404 - loss: 0.1648 - precision_m: 0.9248 - recall_m: 0.9566
# Epoch 80/200
# 91/91 - 0s - 5ms/step - accuracy: 0.9220 - f1_m: 0.9400 - loss: 0.1650 - precision_m: 0.9241 - recall_m: 0.9567
# Epoch 81/200
# 91/91 - 0s - 5ms/step - accuracy: 0.9223 - f1_m: 0.9402 - loss: 0.1648 - precision_m: 0.9244 - recall_m: 0.9568
# Epoch 82/200
# 91/91 - 0s - 5ms/step - accuracy: 0.9222 - f1_m: 0.9401 - loss: 0.1649 - precision_m: 0.9245 - recall_m: 0.9564
# Epoch 83/200
# 91/91 - 0s - 5ms/step - accuracy: 0.9221 - f1_m: 0.9400 - loss: 0.1650 - precision_m: 0.9244 - recall_m: 0.9564
# Epoch 84/200
# 91/91 - 0s - 5ms/step - accuracy: 0.9224 - f1_m: 0.9400 - loss: 0.1648 - precision_m: 0.9245 - recall_m: 0.9563
# Epoch 85/200
# 91/91 - 0s - 5ms/step - accuracy: 0.9225 - f1_m: 0.9405 - loss: 0.1642 - precision_m: 0.9251 - recall_m: 0.9566
# Epoch 86/200
# 91/91 - 0s - 5ms/step - accuracy: 0.9225 - f1_m: 0.9404 - loss: 0.1640 - precision_m: 0.9246 - recall_m: 0.9568
# Epoch 87/200
# 91/91 - 0s - 5ms/step - accuracy: 0.9224 - f1_m: 0.9402 - loss: 0.1646 - precision_m: 0.9254 - recall_m: 0.9557
# Epoch 88/200
# 91/91 - 0s - 5ms/step - accuracy: 0.9227 - f1_m: 0.9405 - loss: 0.1644 - precision_m: 0.9254 - recall_m: 0.9563
# Epoch 89/200
# 91/91 - 0s - 5ms/step - accuracy: 0.9232 - f1_m: 0.9408 - loss: 0.1640 - precision_m: 0.9257 - recall_m: 0.9566
# Epoch 90/200
# 91/91 - 0s - 5ms/step - accuracy: 0.9229 - f1_m: 0.9407 - loss: 0.1639 - precision_m: 0.9260 - recall_m: 0.9559
# Epoch 91/200
# 91/91 - 0s - 5ms/step - accuracy: 0.9229 - f1_m: 0.9407 - loss: 0.1638 - precision_m: 0.9259 - recall_m: 0.9561
# Epoch 92/200
# 91/91 - 0s - 5ms/step - accuracy: 0.9228 - f1_m: 0.9405 - loss: 0.1644 - precision_m: 0.9254 - recall_m: 0.9563
# Epoch 93/200
# 91/91 - 0s - 5ms/step - accuracy: 0.9227 - f1_m: 0.9404 - loss: 0.1641 - precision_m: 0.9257 - recall_m: 0.9559
# Epoch 94/200
# 91/91 - 0s - 5ms/step - accuracy: 0.9231 - f1_m: 0.9408 - loss: 0.1632 - precision_m: 0.9259 - recall_m: 0.9562
# Epoch 95/200
# 91/91 - 0s - 5ms/step - accuracy: 0.9230 - f1_m: 0.9407 - loss: 0.1631 - precision_m: 0.9262 - recall_m: 0.9559
# Epoch 96/200
# 91/91 - 0s - 5ms/step - accuracy: 0.9228 - f1_m: 0.9407 - loss: 0.1635 - precision_m: 0.9260 - recall_m: 0.9562
# Epoch 97/200
# 91/91 - 0s - 5ms/step - accuracy: 0.9229 - f1_m: 0.9406 - loss: 0.1631 - precision_m: 0.9262 - recall_m: 0.9558
# Epoch 98/200
# 91/91 - 0s - 5ms/step - accuracy: 0.9235 - f1_m: 0.9410 - loss: 0.1629 - precision_m: 0.9270 - recall_m: 0.9555
# Epoch 99/200
# 91/91 - 0s - 5ms/step - accuracy: 0.9233 - f1_m: 0.9408 - loss: 0.1629 - precision_m: 0.9262 - recall_m: 0.9560
# Epoch 100/200
# 91/91 - 0s - 5ms/step - accuracy: 0.9230 - f1_m: 0.9407 - loss: 0.1634 - precision_m: 0.9267 - recall_m: 0.9554
# Epoch 101/200
# 91/91 - 0s - 5ms/step - accuracy: 0.9239 - f1_m: 0.9415 - loss: 0.1622 - precision_m: 0.9270 - recall_m: 0.9565
# Epoch 102/200
# 91/91 - 0s - 5ms/step - accuracy: 0.9236 - f1_m: 0.9410 - loss: 0.1624 - precision_m: 0.9269 - recall_m: 0.9557
# Epoch 103/200
# 91/91 - 0s - 5ms/step - accuracy: 0.9236 - f1_m: 0.9413 - loss: 0.1623 - precision_m: 0.9271 - recall_m: 0.9560
# Epoch 104/200
# 91/91 - 0s - 5ms/step - accuracy: 0.9237 - f1_m: 0.9415 - loss: 0.1621 - precision_m: 0.9276 - recall_m: 0.9560
# Epoch 105/200
# 91/91 - 0s - 5ms/step - accuracy: 0.9237 - f1_m: 0.9414 - loss: 0.1618 - precision_m: 0.9275 - recall_m: 0.9558
# Epoch 106/200
# 91/91 - 0s - 5ms/step - accuracy: 0.9239 - f1_m: 0.9414 - loss: 0.1615 - precision_m: 0.9276 - recall_m: 0.9556
# Epoch 107/200
# 91/91 - 0s - 5ms/step - accuracy: 0.9238 - f1_m: 0.9414 - loss: 0.1619 - precision_m: 0.9275 - recall_m: 0.9560
# Epoch 108/200
# 91/91 - 0s - 5ms/step - accuracy: 0.9242 - f1_m: 0.9416 - loss: 0.1613 - precision_m: 0.9282 - recall_m: 0.9556
# Epoch 109/200
# 91/91 - 0s - 5ms/step - accuracy: 0.9237 - f1_m: 0.9411 - loss: 0.1624 - precision_m: 0.9277 - recall_m: 0.9551
# Epoch 110/200
# 91/91 - 0s - 5ms/step - accuracy: 0.9244 - f1_m: 0.9417 - loss: 0.1611 - precision_m: 0.9282 - recall_m: 0.9556
# Epoch 111/200
# 91/91 - 0s - 5ms/step - accuracy: 0.9240 - f1_m: 0.9413 - loss: 0.1617 - precision_m: 0.9278 - recall_m: 0.9554
# Epoch 112/200
# 91/91 - 0s - 5ms/step - accuracy: 0.9241 - f1_m: 0.9414 - loss: 0.1611 - precision_m: 0.9281 - recall_m: 0.9552
# Epoch 113/200
# 91/91 - 0s - 5ms/step - accuracy: 0.9245 - f1_m: 0.9418 - loss: 0.1609 - precision_m: 0.9288 - recall_m: 0.9552
# Epoch 114/200
# 91/91 - 0s - 5ms/step - accuracy: 0.9247 - f1_m: 0.9420 - loss: 0.1610 - precision_m: 0.9291 - recall_m: 0.9553
# Epoch 115/200
# 91/91 - 0s - 5ms/step - accuracy: 0.9244 - f1_m: 0.9417 - loss: 0.1607 - precision_m: 0.9289 - recall_m: 0.9551
# Epoch 116/200
# 91/91 - 0s - 5ms/step - accuracy: 0.9245 - f1_m: 0.9417 - loss: 0.1609 - precision_m: 0.9285 - recall_m: 0.9555
# Epoch 117/200
# 91/91 - 1s - 6ms/step - accuracy: 0.9248 - f1_m: 0.9418 - loss: 0.1606 - precision_m: 0.9296 - recall_m: 0.9545
# Epoch 118/200
# 91/91 - 0s - 5ms/step - accuracy: 0.9246 - f1_m: 0.9418 - loss: 0.1608 - precision_m: 0.9288 - recall_m: 0.9553
# Epoch 119/200
# 91/91 - 0s - 5ms/step - accuracy: 0.9250 - f1_m: 0.9420 - loss: 0.1605 - precision_m: 0.9292 - recall_m: 0.9553
# Epoch 120/200
# 91/91 - 0s - 5ms/step - accuracy: 0.9247 - f1_m: 0.9420 - loss: 0.1601 - precision_m: 0.9298 - recall_m: 0.9547
# Epoch 121/200
# 91/91 - 0s - 5ms/step - accuracy: 0.9252 - f1_m: 0.9420 - loss: 0.1607 - precision_m: 0.9293 - recall_m: 0.9553
# Epoch 122/200
# 91/91 - 0s - 5ms/step - accuracy: 0.9246 - f1_m: 0.9418 - loss: 0.1606 - precision_m: 0.9299 - recall_m: 0.9544
# Epoch 123/200
# 91/91 - 0s - 5ms/step - accuracy: 0.9250 - f1_m: 0.9423 - loss: 0.1593 - precision_m: 0.9298 - recall_m: 0.9552
# Epoch 124/200
# 91/91 - 0s - 5ms/step - accuracy: 0.9252 - f1_m: 0.9423 - loss: 0.1596 - precision_m: 0.9301 - recall_m: 0.9549
# Epoch 125/200
# 91/91 - 1s - 7ms/step - accuracy: 0.9251 - f1_m: 0.9423 - loss: 0.1598 - precision_m: 0.9302 - recall_m: 0.9548
# Epoch 126/200
# 91/91 - 0s - 5ms/step - accuracy: 0.9252 - f1_m: 0.9422 - loss: 0.1598 - precision_m: 0.9301 - recall_m: 0.9548
# Epoch 127/200
# 91/91 - 0s - 5ms/step - accuracy: 0.9251 - f1_m: 0.9421 - loss: 0.1596 - precision_m: 0.9300 - recall_m: 0.9547
# Epoch 128/200
# 91/91 - 0s - 5ms/step - accuracy: 0.9251 - f1_m: 0.9421 - loss: 0.1595 - precision_m: 0.9302 - recall_m: 0.9546
# Epoch 129/200
# 91/91 - 0s - 5ms/step - accuracy: 0.9251 - f1_m: 0.9423 - loss: 0.1594 - precision_m: 0.9302 - recall_m: 0.9549
# Epoch 130/200
# 91/91 - 0s - 5ms/step - accuracy: 0.9256 - f1_m: 0.9424 - loss: 0.1591 - precision_m: 0.9309 - recall_m: 0.9544
# Epoch 131/200
# 91/91 - 0s - 5ms/step - accuracy: 0.9255 - f1_m: 0.9425 - loss: 0.1592 - precision_m: 0.9310 - recall_m: 0.9544
# Epoch 132/200
# 91/91 - 0s - 5ms/step - accuracy: 0.9257 - f1_m: 0.9426 - loss: 0.1587 - precision_m: 0.9308 - recall_m: 0.9548
# Epoch 133/200
# 91/91 - 0s - 5ms/step - accuracy: 0.9254 - f1_m: 0.9424 - loss: 0.1589 - precision_m: 0.9312 - recall_m: 0.9540
# Epoch 134/200
# 91/91 - 0s - 5ms/step - accuracy: 0.9258 - f1_m: 0.9427 - loss: 0.1585 - precision_m: 0.9313 - recall_m: 0.9544
# Epoch 135/200
# 91/91 - 0s - 5ms/step - accuracy: 0.9259 - f1_m: 0.9426 - loss: 0.1584 - precision_m: 0.9315 - recall_m: 0.9542
# Epoch 136/200
# 91/91 - 0s - 5ms/step - accuracy: 0.9256 - f1_m: 0.9425 - loss: 0.1584 - precision_m: 0.9310 - recall_m: 0.9545
# Epoch 137/200
# 91/91 - 0s - 5ms/step - accuracy: 0.9262 - f1_m: 0.9429 - loss: 0.1580 - precision_m: 0.9321 - recall_m: 0.9541
# Epoch 138/200
# 91/91 - 0s - 5ms/step - accuracy: 0.9263 - f1_m: 0.9432 - loss: 0.1577 - precision_m: 0.9324 - recall_m: 0.9542
# Epoch 139/200
# 91/91 - 0s - 5ms/step - accuracy: 0.9260 - f1_m: 0.9430 - loss: 0.1578 - precision_m: 0.9317 - recall_m: 0.9547
# Epoch 140/200
# 91/91 - 0s - 5ms/step - accuracy: 0.9265 - f1_m: 0.9430 - loss: 0.1576 - precision_m: 0.9321 - recall_m: 0.9544
# Epoch 141/200
# 91/91 - 0s - 5ms/step - accuracy: 0.9267 - f1_m: 0.9433 - loss: 0.1573 - precision_m: 0.9325 - recall_m: 0.9544
# Epoch 142/200
# 91/91 - 0s - 5ms/step - accuracy: 0.9260 - f1_m: 0.9426 - loss: 0.1578 - precision_m: 0.9318 - recall_m: 0.9539
# Epoch 143/200
# 91/91 - 0s - 5ms/step - accuracy: 0.9265 - f1_m: 0.9430 - loss: 0.1580 - precision_m: 0.9322 - recall_m: 0.9542
# Epoch 144/200
# 91/91 - 0s - 5ms/step - accuracy: 0.9265 - f1_m: 0.9429 - loss: 0.1571 - precision_m: 0.9327 - recall_m: 0.9534
# Epoch 145/200
# 91/91 - 0s - 5ms/step - accuracy: 0.9263 - f1_m: 0.9428 - loss: 0.1570 - precision_m: 0.9328 - recall_m: 0.9531
# Epoch 146/200
# 91/91 - 0s - 5ms/step - accuracy: 0.9266 - f1_m: 0.9432 - loss: 0.1570 - precision_m: 0.9328 - recall_m: 0.9540
# Epoch 147/200
# 91/91 - 0s - 5ms/step - accuracy: 0.9267 - f1_m: 0.9432 - loss: 0.1567 - precision_m: 0.9330 - recall_m: 0.9538
# Epoch 148/200
# 91/91 - 0s - 5ms/step - accuracy: 0.9268 - f1_m: 0.9436 - loss: 0.1560 - precision_m: 0.9337 - recall_m: 0.9537
# Epoch 149/200
# 91/91 - 0s - 5ms/step - accuracy: 0.9264 - f1_m: 0.9431 - loss: 0.1565 - precision_m: 0.9334 - recall_m: 0.9532
# Epoch 150/200
# 91/91 - 0s - 5ms/step - accuracy: 0.9268 - f1_m: 0.9433 - loss: 0.1562 - precision_m: 0.9333 - recall_m: 0.9536
# Epoch 151/200
# 91/91 - 0s - 5ms/step - accuracy: 0.9266 - f1_m: 0.9430 - loss: 0.1564 - precision_m: 0.9336 - recall_m: 0.9528
# Epoch 152/200
# 91/91 - 1s - 7ms/step - accuracy: 0.9271 - f1_m: 0.9436 - loss: 0.1558 - precision_m: 0.9343 - recall_m: 0.9532
# Epoch 153/200
# 91/91 - 0s - 5ms/step - accuracy: 0.9266 - f1_m: 0.9431 - loss: 0.1560 - precision_m: 0.9337 - recall_m: 0.9529
# Epoch 154/200
# 91/91 - 0s - 5ms/step - accuracy: 0.9267 - f1_m: 0.9433 - loss: 0.1558 - precision_m: 0.9338 - recall_m: 0.9531
# Epoch 155/200
# 91/91 - 0s - 5ms/step - accuracy: 0.9273 - f1_m: 0.9437 - loss: 0.1555 - precision_m: 0.9347 - recall_m: 0.9530
# Epoch 156/200
# 91/91 - 0s - 5ms/step - accuracy: 0.9274 - f1_m: 0.9437 - loss: 0.1556 - precision_m: 0.9341 - recall_m: 0.9537
# Epoch 157/200
# 91/91 - 0s - 5ms/step - accuracy: 0.9272 - f1_m: 0.9434 - loss: 0.1555 - precision_m: 0.9342 - recall_m: 0.9530
# Epoch 158/200
# 91/91 - 0s - 5ms/step - accuracy: 0.9271 - f1_m: 0.9434 - loss: 0.1554 - precision_m: 0.9347 - recall_m: 0.9523
# Epoch 159/200
# 91/91 - 0s - 5ms/step - accuracy: 0.9269 - f1_m: 0.9433 - loss: 0.1557 - precision_m: 0.9343 - recall_m: 0.9527
# Epoch 160/200
# 91/91 - 0s - 5ms/step - accuracy: 0.9278 - f1_m: 0.9439 - loss: 0.1548 - precision_m: 0.9351 - recall_m: 0.9531
# Epoch 161/200
# 91/91 - 0s - 5ms/step - accuracy: 0.9276 - f1_m: 0.9438 - loss: 0.1546 - precision_m: 0.9350 - recall_m: 0.9527
# Epoch 162/200
# 91/91 - 0s - 5ms/step - accuracy: 0.9275 - f1_m: 0.9437 - loss: 0.1549 - precision_m: 0.9353 - recall_m: 0.9526
# Epoch 163/200
# 91/91 - 0s - 5ms/step - accuracy: 0.9267 - f1_m: 0.9433 - loss: 0.1551 - precision_m: 0.9346 - recall_m: 0.9524
# Epoch 164/200
# 91/91 - 0s - 5ms/step - accuracy: 0.9276 - f1_m: 0.9438 - loss: 0.1545 - precision_m: 0.9354 - recall_m: 0.9525
# Epoch 165/200
# 91/91 - 0s - 5ms/step - accuracy: 0.9278 - f1_m: 0.9441 - loss: 0.1537 - precision_m: 0.9356 - recall_m: 0.9529
# Epoch 166/200
# 91/91 - 0s - 5ms/step - accuracy: 0.9274 - f1_m: 0.9437 - loss: 0.1541 - precision_m: 0.9348 - recall_m: 0.9529
# Epoch 167/200
# 91/91 - 0s - 4ms/step - accuracy: 0.9279 - f1_m: 0.9440 - loss: 0.1538 - precision_m: 0.9359 - recall_m: 0.9523
# Epoch 168/200
# 91/91 - 0s - 4ms/step - accuracy: 0.9278 - f1_m: 0.9439 - loss: 0.1539 - precision_m: 0.9355 - recall_m: 0.9526
# Epoch 169/200
# 91/91 - 0s - 5ms/step - accuracy: 0.9279 - f1_m: 0.9440 - loss: 0.1534 - precision_m: 0.9360 - recall_m: 0.9523
# Epoch 170/200
# 91/91 - 0s - 5ms/step - accuracy: 0.9278 - f1_m: 0.9440 - loss: 0.1532 - precision_m: 0.9361 - recall_m: 0.9523
# Epoch 171/200
# 91/91 - 0s - 5ms/step - accuracy: 0.9283 - f1_m: 0.9444 - loss: 0.1530 - precision_m: 0.9367 - recall_m: 0.9523
# Epoch 172/200
# 91/91 - 0s - 5ms/step - accuracy: 0.9270 - f1_m: 0.9432 - loss: 0.1544 - precision_m: 0.9351 - recall_m: 0.9519
# Epoch 173/200
# 91/91 - 0s - 4ms/step - accuracy: 0.9278 - f1_m: 0.9440 - loss: 0.1528 - precision_m: 0.9363 - recall_m: 0.9519
# Epoch 174/200
# 91/91 - 0s - 5ms/step - accuracy: 0.9283 - f1_m: 0.9443 - loss: 0.1525 - precision_m: 0.9368 - recall_m: 0.9520
# Epoch 175/200
# 91/91 - 0s - 4ms/step - accuracy: 0.9284 - f1_m: 0.9444 - loss: 0.1526 - precision_m: 0.9370 - recall_m: 0.9521
# Epoch 176/200
# 91/91 - 0s - 5ms/step - accuracy: 0.9280 - f1_m: 0.9441 - loss: 0.1529 - precision_m: 0.9363 - recall_m: 0.9521
# Epoch 177/200
# 91/91 - 0s - 4ms/step - accuracy: 0.9283 - f1_m: 0.9443 - loss: 0.1524 - precision_m: 0.9370 - recall_m: 0.9518
# Epoch 178/200
# 91/91 - 0s - 4ms/step - accuracy: 0.9281 - f1_m: 0.9443 - loss: 0.1521 - precision_m: 0.9370 - recall_m: 0.9518
# Epoch 179/200
# 91/91 - 0s - 4ms/step - accuracy: 0.9284 - f1_m: 0.9444 - loss: 0.1516 - precision_m: 0.9377 - recall_m: 0.9514
# Epoch 180/200
# 91/91 - 0s - 5ms/step - accuracy: 0.9283 - f1_m: 0.9443 - loss: 0.1520 - precision_m: 0.9370 - recall_m: 0.9518
# Epoch 181/200
# 91/91 - 0s - 5ms/step - accuracy: 0.9283 - f1_m: 0.9444 - loss: 0.1519 - precision_m: 0.9378 - recall_m: 0.9512
# Epoch 182/200
# 91/91 - 0s - 5ms/step - accuracy: 0.9286 - f1_m: 0.9446 - loss: 0.1512 - precision_m: 0.9378 - recall_m: 0.9516
# Epoch 183/200
# 91/91 - 0s - 5ms/step - accuracy: 0.9285 - f1_m: 0.9445 - loss: 0.1514 - precision_m: 0.9381 - recall_m: 0.9512
# Epoch 184/200
# 91/91 - 0s - 4ms/step - accuracy: 0.9287 - f1_m: 0.9446 - loss: 0.1514 - precision_m: 0.9381 - recall_m: 0.9514
# Epoch 185/200
# 91/91 - 0s - 4ms/step - accuracy: 0.9281 - f1_m: 0.9441 - loss: 0.1517 - precision_m: 0.9377 - recall_m: 0.9507
# Epoch 186/200
# 91/91 - 0s - 4ms/step - accuracy: 0.9286 - f1_m: 0.9447 - loss: 0.1510 - precision_m: 0.9379 - recall_m: 0.9518
# Epoch 187/200
# 91/91 - 0s - 4ms/step - accuracy: 0.9283 - f1_m: 0.9444 - loss: 0.1512 - precision_m: 0.9381 - recall_m: 0.9511
# Epoch 188/200
# 91/91 - 0s - 5ms/step - accuracy: 0.9284 - f1_m: 0.9446 - loss: 0.1504 - precision_m: 0.9382 - recall_m: 0.9512
# Epoch 189/200
# 91/91 - 1s - 7ms/step - accuracy: 0.9289 - f1_m: 0.9448 - loss: 0.1508 - precision_m: 0.9388 - recall_m: 0.9510
# Epoch 190/200
# 91/91 - 1s - 6ms/step - accuracy: 0.9290 - f1_m: 0.9448 - loss: 0.1506 - precision_m: 0.9386 - recall_m: 0.9512
# Epoch 191/200
# 91/91 - 0s - 5ms/step - accuracy: 0.9281 - f1_m: 0.9442 - loss: 0.1508 - precision_m: 0.9380 - recall_m: 0.9506
# Epoch 192/200
# 91/91 - 0s - 5ms/step - accuracy: 0.9290 - f1_m: 0.9449 - loss: 0.1502 - precision_m: 0.9390 - recall_m: 0.9510
# Epoch 193/200
# 91/91 - 0s - 5ms/step - accuracy: 0.9286 - f1_m: 0.9444 - loss: 0.1508 - precision_m: 0.9384 - recall_m: 0.9506
# Epoch 194/200
# 91/91 - 0s - 5ms/step - accuracy: 0.9287 - f1_m: 0.9445 - loss: 0.1502 - precision_m: 0.9381 - recall_m: 0.9512
# Epoch 195/200
# 91/91 - 0s - 5ms/step - accuracy: 0.9285 - f1_m: 0.9444 - loss: 0.1502 - precision_m: 0.9387 - recall_m: 0.9503
# Epoch 196/200
# 91/91 - 0s - 5ms/step - accuracy: 0.9291 - f1_m: 0.9451 - loss: 0.1497 - precision_m: 0.9395 - recall_m: 0.9508
# Epoch 197/200
# 91/91 - 0s - 5ms/step - accuracy: 0.9289 - f1_m: 0.9448 - loss: 0.1494 - precision_m: 0.9391 - recall_m: 0.9506
# Epoch 198/200
# 91/91 - 0s - 5ms/step - accuracy: 0.9292 - f1_m: 0.9447 - loss: 0.1496 - precision_m: 0.9390 - recall_m: 0.9506
# Epoch 199/200
# 91/91 - 0s - 5ms/step - accuracy: 0.9294 - f1_m: 0.9450 - loss: 0.1494 - precision_m: 0.9397 - recall_m: 0.9506
# Epoch 200/200
# 91/91 - 0s - 5ms/step - accuracy: 0.9289 - f1_m: 0.9446 - loss: 0.1498 - precision_m: 0.9385 - recall_m: 0.9509
# 2416/2416 ━━━━━━━━━━━━━━━━━━━━ 6s 2ms/step - accuracy: 0.9319 - f1_m: 0.9451 - loss: 0.1473 - precision_m: 0.9485 - recall_m: 0.9444

# %%
logistic_performance_dropped_attack_cat = train_and_evaluate(X_train_dropped_attack_cat, X_test_dropped_attack_cat, y_train_dropped_attack_cat, y_test_dropped_attack_cat, 'Logistic Regression')

# %%
knn_performance_dropped_attack_cat = train_and_evaluate(X_train_dropped_attack_cat, X_test_dropped_attack_cat, y_train_dropped_attack_cat, y_test_dropped_attack_cat, 'KNN', normalize=True)

# %%
decision_tree_performance_dropped_attack_cat = train_and_evaluate(X_train_dropped_attack_cat, X_test_dropped_attack_cat, y_train_dropped_attack_cat, y_test_dropped_attack_cat, 'Decision Tree')

# %%
# Append the results to the list
results_list.append(rf_performance_dropped_attack_cat)
results_list.append(mlp_performance_dropped_attack_cat)
results_list.append(lstm_performance_dropped_attack_cat)
results_list.append(logistic_performance_dropped_attack_cat)
results_list.append(knn_performance_dropped_attack_cat)
results_list.append(decision_tree_performance_dropped_attack_cat)

# Create a DataFrame from the list
results_df = pd.DataFrame(results_list)

# %%
results_df
# Out:
#                  Model  Accuracy  F1 Score  Precision    Recall      Loss
# 0        Random Forest  0.951010  0.951035   0.951065  0.951010  1.765767
# 1                  MLP  0.931218  0.931069   0.931018  0.931218  0.143435
# 2                 LSTM  0.931257  0.944918   0.947389  0.945133  0.148521
# 3  Logistic Regression  0.804235  0.790590   0.816112  0.804235  7.056074
# 4                  KNN  0.918152  0.918234   0.918339  0.918152  2.950094
# 5        Decision Tree  0.936431  0.936438   0.936444  0.936431  2.291254

# %%
from sklearn.metrics import roc_curve, auc
import numpy as np
from sklearn.metrics import f1_score
from sklearn.model_selection import StratifiedKFold
from sklearn.model_selection import train_test_split
from sklearn.mixture import BayesianGaussianMixture
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import precision_recall_fscore_support
import matplotlib.pyplot as plt

# Assuming your features are stored in X and labels in y
XX = shuffled_df.drop(['label'], axis=1)
yy = shuffled_df['label']

# Train-Test Split
XX_train, XX_test, yy_train, yy_test = train_test_split(XX, yy, test_size=0.2, random_state=42)

# Feature Scaling
scaler = StandardScaler()
XX_train_scaled = scaler.fit_transform(XX_train)
XX_test_scaled = scaler.transform(XX_test)

# Train Beta Mixture Model
bmm = BayesianGaussianMixture(n_components=2, max_iter=100, random_state=42)
bmm.fit(XX_train_scaled[yy_train == 0])

anomaly_scores = -bmm.score_samples(XX_test_scaled)
yy_test = yy_test.reset_index(drop=True)  # Reset the index of yy_test

# Perform 10-fold cross-validation
kf = StratifiedKFold(n_splits=10, shuffle=True, random_state=42)

# Lists to store results for each fold
roc_auc_list = []
optimal_threshold_list = []

# Variables to store values for the best threshold
best_fpr = None
best_tpr = None
best_threshold = None
best_roc_auc = 0.0

for train_index, test_index in kf.split(XX_test_scaled, yy_test):
    X_train_fold, X_test_fold = XX_test_scaled[train_index], XX_test_scaled[test_index]
    y_train_fold, y_test_fold = yy_test[train_index], yy_test[test_index]

    anomaly_scores_fold = -bmm.score_samples(X_test_fold)

    fpr, tpr, thresholds = roc_curve(y_test_fold, anomaly_scores_fold)
    roc_auc = auc(fpr, tpr)

    # Find the threshold that maximizes the Youden's Index (sensitivity + specificity - 1)
    Youden_Index = tpr - fpr
    optimal_threshold = thresholds[np.argmax(Youden_Index)]

    roc_auc_list.append(roc_auc)
    optimal_threshold_list.append(optimal_threshold)

    # Update best threshold if the current fold has a higher ROC AUC
    if roc_auc > best_roc_auc:
        best_roc_auc = roc_auc
        best_fpr = fpr
        best_tpr = tpr
        best_threshold = optimal_threshold

# Plot the ROC curve for the best fold
plt.figure(figsize=(8, 6))
plt.plot(best_fpr, best_tpr, color='darkorange', lw=2, label='ROC curve (area = {:.2f})'.format(best_roc_auc))
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic')
plt.legend(loc='lower right')
plt.show()

# Find the average ROC AUC across all folds
average_roc_auc = np.mean(roc_auc_list)
print(f'Average ROC AUC: {average_roc_auc}')

# Find the average optimal threshold across all folds
average_optimal_threshold = np.mean(optimal_threshold_list)
print(f'Average Optimal Threshold: {average_optimal_threshold}')

# Print the best threshold
print(f'Best Threshold: {best_threshold}')
# Out:
# Average ROC AUC: 0.8927746090463262
# Average Optimal Threshold: -13.022768698839181
# Best Threshold: -17.55047737763994

# %%
# Default threshold
default_threshold = 0.5
default_predictions = (anomaly_scores > default_threshold).astype(int)
default_accuracy = accuracy_score(yy_test, default_predictions)
default_precision = precision_score(yy_test, default_predictions)
default_recall = recall_score(yy_test, default_predictions)
default_f1 = f1_score(yy_test, default_predictions)

# Avg optimal
average_optimal_predictions = (anomaly_scores > average_optimal_threshold).astype(int)
average_optimal_accuracy = accuracy_score(yy_test, average_optimal_predictions)
average_optimal_precision = precision_score(yy_test, average_optimal_predictions)
average_optimal_recall = recall_score(yy_test, average_optimal_predictions)
average_optimal_f1 = f1_score(yy_test, average_optimal_predictions)

# Best
best_predictions = (anomaly_scores > best_threshold).astype(int)
best_accuracy = accuracy_score(yy_test, best_predictions)
best_precision = precision_score(yy_test, best_predictions)
best_recall = recall_score(yy_test, best_predictions)
best_f1 = f1_score(yy_test, best_predictions)

results_ = pd.DataFrame({
    'Metric': ['Accuracy', 'Precision', 'Recall', 'F1-score'],
    'Default_Threshold': [default_accuracy, default_precision, default_recall, default_f1],
    'Optimal_Threshold': [average_optimal_accuracy, average_optimal_precision, average_optimal_recall, average_optimal_f1],
    'Best_Threshold': [best_accuracy, best_precision, best_recall, best_f1]
})

# %%
results_
# Out:
#       Metric  Default_Threshold  Optimal_Threshold  Best_Threshold
# 0   Accuracy           0.714912           0.780402        0.781217
# 1  Precision           0.940653           0.927373        0.912781
# 2     Recall           0.590891           0.711907        0.726886
# 3   F1-score           0.725834           0.805480        0.809296

# %% [markdown]
# In summary, the results suggest that the model's performance improves when using an optimal threshold, and the best threshold provides a balanced trade-off between precision and recall.
